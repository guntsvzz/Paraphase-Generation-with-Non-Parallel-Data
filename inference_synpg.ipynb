# %%
import torch, torchdata, torchtext
from torch import nn
import torch.nn.functional as F
from tqdm import tqdm
import random, math, time
from torch.autograd import Variable
import operator
import numpy as np

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)

#make our work comparable if restarted the kernel
SEED = 6969
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
# Out:
# cuda:0

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, dim_model, dropout = 0.1, max_len = 5000):
        super().__init__()
        self.dropout = nn.Dropout(dropout)
        
        # Encoding - From formula
        pos_encoding = torch.zeros(max_len, dim_model)
        positions_list = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        division_term = torch.exp(torch.arange(0, dim_model, 2).float() * (-np.log(10000.0)) / dim_model) # 1000^(2i/dim_model)
        
        # PE(pos, 2i) = sin(pos/1000^(2i/dim_model))
        pos_encoding[:, 0::2] = torch.sin(positions_list * division_term)
        
        # PE(pos, 2i + 1) = cos(pos/1000^(2i/dim_model))
        pos_encoding[:, 1::2] = torch.cos(positions_list * division_term)
        
        # Saving buffer (same as parameter without gradients needed)
        pos_encoding = pos_encoding.unsqueeze(0).transpose(0, 1)
        self.register_buffer("pos_encoding",pos_encoding)
        
    def forward(self, token_embedding):
        # Residual connection + pos encoding
        token_embedding = token_embedding + self.pos_encoding[:token_embedding.size(0), :]
        return self.dropout(token_embedding)

# %%
class seq2seqTransformer(nn.Module):
    def __init__(self, input_dim, emb_dim, device, word_dropout = 0.4, dropout = 0.1):
        super(seq2seqTransformer, self).__init__()
        self.input_dim = input_dim 
        self.emb_dim = emb_dim 
        self.word_dropout = word_dropout
        self.dropout = dropout
        self.device = device
        
        self.scale = np.sqrt(self.emb_dim)
        # self.scale = torch.sqrt(torch.IntTensor([self.hid_dim])).to(device)

        # vcocabulary embedding
        self.embedding_encoder = nn.Embedding(input_dim, emb_dim)
        self.embedding_decoder = nn.Embedding(input_dim, emb_dim)
        # positional encoding
        self.pos_encoder = PositionalEncoding(emb_dim, dropout = 0.0)

        self.transformer = nn.Transformer(d_model = emb_dim, nhead = 12, dropout = dropout)
        # linear Transformation
        self.linear = nn.Linear(emb_dim, input_dim)
        self.init_weights()

    def load_embedding(self, embedding):  #synPG applied with GloVe glove.840B.300d.txt
        self.embedding_encoder.weight.data.copy_(torch.from_numpy(embedding)) 
        self.embedding_decoder.weight.data.copy_(torch.from_numpy(embedding))  

    def init_weights(self):
        initrange = 0.1
        # initialize cocabulary matrix weight
        self.embedding_encoder.weight.data.uniform_(-initrange, initrange)
        self.embedding_decoder.weight.data.uniform_(-initrange, initrange)
        # initialize linear weight
        self.linear.weight.data.uniform_(-initrange, initrange)
        self.linear.bias.data.fill_(0)

    def generate_square_mask(self, max_sent_len, max_synt_len):
        size = max_sent_len + max_synt_len + 2 #<sos> and <eos>
        mask = torch.zeros((size, size))
        mask[:max_sent_len, max_sent_len:] = float("-inf")
        mask[max_sent_len:, :max_sent_len] = float("-inf")
        return mask
        
    def forward(self, sents, synts, trg):
        #sents  : batch_size, seq_len
        #synts  : batch_size, seq_len
        #trgs   : batch_size, seq_len 
        batch_size   = sents.size(0)
        max_sent_len = sents.size(1)
        max_synt_len = synts.size(1) - 2    # count without <sos> and <eos>
        max_targ_len = trg.size(1) - 2      # count without <sos> and <eos>

        # apply word dropout
        drop_mask = torch.bernoulli(self.word_dropout * torch.ones(max_sent_len)).bool().to(self.device)
        #sents = sents.masked_fill(drop_mask, -1e10)
        sents = sents.masked_fill(drop_mask, 0)

        #print(sents.shape)
        #print(self.embedding_encoder(sents).shape)

        # sentence, syntax => embedding
        sent_embeddings = self.embedding_encoder(sents).transpose(0, 1) * self.scale
        #sent_emb = [seq_len, batch size, emb_size]
        synt_embeddings = self.embedding_encoder(synts).transpose(0, 1) * self.scale
        synt_embeddings = self.pos_encoder(synt_embeddings) 
        #synt_emb = [seq_len, batch size, emb_size]
        en_embeddings = torch.cat((sent_embeddings, synt_embeddings), dim=0)
        #en_emb = [seq_len, batch size, emb_size*2]

        # do not allow cross attetion
        src_mask = self.generate_square_mask(max_sent_len, max_synt_len).to(self.device)
        
        # target => embedding
        de_embeddings = self.embedding_decoder(trg[:, :-1]).transpose(0, 1) * self.scale
        de_embeddings = self.pos_encoder(de_embeddings)
        
        # sequential mask
        trg_mask = self.transformer.generate_square_subsequent_mask(max_targ_len+1).to(self.device)
        
        # forward
        outputs = self.transformer(en_embeddings, de_embeddings, src_mask=src_mask, tgt_mask=trg_mask)
        
        # apply linear layer to vocabulary size
        outputs = outputs.transpose(0, 1)
        outputs = self.linear(outputs.contiguous().view(-1, self.emb_dim))
        outputs = outputs.view(batch_size, max_targ_len + 1, self.input_dim)
        #output = [batch size, trg_len, vocab_size]
        return outputs
    
    def generate(self, sents, synts, max_len = 30, sample=True, temp=0.5):
        #sents  : batch_size, seq_len
        #synts  : batch_size, seq_len
        batch_size   = sents.size(0)
        max_sent_len = sents.size(1)
        max_synt_len = synts.size(1) - 2  # count without <sos> and <eos>
        max_targ_len = max_len
        
        # output index starts with <sos>
        idxs = torch.zeros((batch_size, max_targ_len+2), dtype=torch.long).to(self.device)
        idxs[:, 0] = 1
        
        # sentence, syntax => embedding
        sent_embeddings = self.embedding_encoder(sents).transpose(0, 1) * self.scale
        synt_embeddings = self.embedding_encoder(synts).transpose(0, 1) * self.scale
        synt_embeddings = self.pos_encoder(synt_embeddings)
        en_embeddings = torch.cat((sent_embeddings, synt_embeddings), dim=0)
        
        # do not allow cross attetion
        src_mask = self.generate_square_mask(max_sent_len, max_synt_len).to(self.device)
        
        # starting index => embedding
        de_embeddings = self.embedding_decoder(idxs[:, :1]).transpose(0, 1) * self.scale
        de_embeddings = self.pos_encoder(de_embeddings)
        
        # sequential mask
        trg_mask = self.transformer.generate_square_subsequent_mask(de_embeddings.size(0)).to(self.device)
        
        # encode
        memory = self.transformer.encoder(en_embeddings, mask=src_mask)
        
        # auto-regressively generate output
        for i in range(1, max_targ_len+2):
            if i % 5 == 0:
                print(f'epoch : {i}')
            # decode
            outputs = self.transformer.decoder(de_embeddings, memory, tgt_mask=trg_mask)
            outputs = self.linear(outputs[-1].contiguous().view(-1, self.emb_dim))
            
            # get argmax index or sample index
            if not sample:
                values, idx = torch.max(outputs, 1)
            else:
                probs = F.softmax(outputs/temp, dim=1)
                idx = torch.multinomial(probs, 1).squeeze(1)
            
            # save to output index
            idxs[:, i] = idx
            
            # concatenate index to decoding
            de_embeddings = self.embedding_decoder(idxs[:, :i+1]).transpose(0, 1) * self.scale
            de_embeddings = self.pos_encoder(de_embeddings)
            
            # new sequential mask
            trg_mask = self.transformer.generate_square_subsequent_mask(de_embeddings.size(0)).to(self.device)
        
        return idxs[:, 1:]

# %%
import pickle
from utils import synt2str, sent2str, load_embedding
from apply_bpe import BPE, read_vocabulary
from gensim.test.utils import datapath

#you have to put this file in some python/gensim directory; just run it and it will inform where to put....
glove_file = datapath('/root/projects/NLP_projects/synpg/glove.6B.300d.txt')

#with open("train_data.pkl", "wb") as file:
# file = open("train_data.pkl", "wb")
# pickle.dump(train_data, file)
file = open("train_data.pkl", "rb")
train_data = pickle.load(file)

with open("dictionary.pkl", "rb") as file:
    syndict = pickle.load(file)

vocab_dict = syndict.word2idx

# %%
#device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device = "cpu"
print(device)

from utils import load_embedding

input_dim   = len(vocab_dict)
emb_dim     = 300  #fasttext
word_dropout = 0.4 #following SynPG
dropout      = 0.1

pad_idx = vocab_dict['<pad>'] ##get the pad index from the vocab

embedding = load_embedding(glove_file, syndict)

criterion = nn.CrossEntropyLoss(ignore_index = pad_idx) #combine softmax with cross entropy

model = seq2seqTransformer(input_dim=input_dim, emb_dim = emb_dim, device=device, word_dropout = word_dropout, dropout = dropout)
model = model.to(device)
model.load_embedding(embedding)
# model.embedding_encoder.weight.data = fast_embedding #apply fasttext instead of Glove 840b 300d.txt (5.56 GB) TT
# model.embedding_decoder.weight.data = fast_embedding
# Out:
# cpu
# load 22696 of 31414 from pretrained word embeddings

# %%
from utils import synt2str, sent2str, load_embedding

def generate(model, loader, criterion, loader_length,vocab_transform):
    #turn off dropout (and batch norm if used)
    model.eval()
    epoch_loss = 0
    
    with torch.no_grad():

        for sents_, synts_, trgs_ in loader:

            batch_size   = sents_.size(0)
            max_sent_len = sents_.size(1)
            max_synt_len = synts_.size(1) - 2  # count without <sos> and <eos>
            
            # generate
            idxs = model.generate(sents_, synts_, sents_.size(1), temp=0.5)
            
            # write output
            for sent, idx, synt in zip(sents_.cpu().numpy(), idxs.cpu().numpy(), synts_.cpu().numpy()):
                print(synt2str(synt[1:], vocab_transform)+'\n')
                print(sent2str(sent, vocab_transform)+'\n')
                print(synt2str(idx, vocab_transform)+'\n')
                print("--\n")

# %%
text_pipeline = lambda x: [vocab_dict[x_] if x_ in vocab_dict else vocab_dict["<unk>"] for x_ in x ]

# %%
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
import torch

pad_idx = vocab_dict['<pad>'] ##get the pad index from the vocab

def collate_batch(batch):
    sent_list, synt_lst, trg_list = [], [], []
    # print(len(batch))
    # sens_, syns_, trgs_ = batch
    # for sen_, syn_, trg_ in zip(sens_, syns_, trgs_):
    for sen_, syn_, trg_ in batch:
        processed_sent = torch.tensor(text_pipeline(sen_), dtype=torch.int64)
        sent_list.append(processed_sent)
        processed_synt = torch.tensor(text_pipeline(syn_), dtype=torch.int64)
        synt_lst.append(processed_synt)
        processed_trg = torch.tensor(text_pipeline(trg_), dtype=torch.int64)
        trg_list.append(processed_trg)

    return pad_sequence(sent_list, padding_value=pad_idx, batch_first=True), pad_sequence(synt_lst, padding_value=pad_idx, batch_first=True), pad_sequence(trg_list, padding_value=pad_idx, batch_first=True)

# %%
from torch.utils.data import DataLoader

train_range = int(len(train_data) * 0.7)

train_set = train_data[0:train_range]
val_set   = train_data[train_range:]
# test_set = train_data[90:]

train_dataloader = DataLoader(train_set, batch_size=32, shuffle=True, collate_fn=collate_batch)
valid_dataloader = DataLoader(val_set, batch_size=32, shuffle=True, collate_fn=collate_batch)
#test_dataloader = DataLoader(test_set, batch_size=4, shuffle=False, collate_fn=collate_batch)

# %%
train_loader_length = len(list(iter(train_dataloader)))
val_loader_length   = len(list(iter(valid_dataloader)))
#test_loader_length  = len(list(iter(test_dataloader)))
#train_loader_length, val_loader_length, test_loader_length

# %%
model_path = "/root/projects/NLP_projects/synpg/models/prototype_synpg.pt"
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
generate(model, valid_dataloader, criterion, val_loader_length, syndict)
# Out:
# epoch : 5
# epoch : 10
# epoch : 15
# epoch : 20
# epoch : 25
# epoch : 30
# ROOT ( FRAG ( ADVP ( RB ) ) ( : ) ( SBAR ( WHADVP ( WRB ) ) ( S ( NP ( PRP ) ) ( VP ( VBP ) ( ADJP ( JJ ) ) ) ) ) ( , ) ( NP ( PRP ) ) ( VP ( VBP ) ( ADJP ( JJ ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# again ... when you 're right , you 're right .
#
#
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VP ( VBD ) ( NP ( NP ( DT ) ( NN ) ( NN ) ) ( PP ( IN ) ( NP ( PRP ) ) ) ) ) ( CC ) ( ADVP ( RB ) ) ( VP ( VBD ) ( NP ( DT ) ( NN ) ( <unk> ) ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# they did a tv special about him and even showed a re-@@ run !
#
# . , .
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBD ) ( NP ( NP ( DT ) ( NN ) ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ( PP ( IN ) ( NP ( PRP$ ) ( JJ ) ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# he pressed the hold button on the panel with his free hand .
#
# in it know
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBP ) ( RB ) ( VP ( VB ) ( NP ( PRP ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# we do not have it .
#
# a .
#
# --
#
# ROOT ( S ( ADVP ( RB ) ) ( , ) ( NP ( PRP ) ) ( VP ( VBD ) ( ADVP ( RB ) ) ( VP ( VBG ) ( S ( VP ( VBG ) ( PRT ( RP ) ) ( PP ( IN ) ( ADVP ( RB ) ) ) ) ) ) ) ( , ) ( CC ) ( , ) ( INTJ ( UH ) ) ( , ) ( WHADVP ( WRB ) ) ( SQ ( VBP ) ( RB ) ( NP ( PRP ) ) ( VP ( VP ( VB ) ( PRT ( RP ) ) ( PP ( IN ) ) ) ( , ) ( VP ( VB ) ( NP ( DT ) ( NN ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad>
#
# so , i was just finishing cleaning up in here , but , uh , why do n't you come on in , have a seat ?
#
#
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBP ) ( S ( VP ( TO ) ( VP ( VB ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( PP ( IN ) ( NP ( NP ( NN ) ( POS ) ) ( JJ ) ( <unk> ) ( NNS ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# i have to talk to the tutor about jude 's mid-@@ terms .
#
#
#
# --
#
# ROOT ( S ( UH ) ( UH ) ( ADVP ( RB ) ) ( , ) ( VP ( VBP ) ( RB ) ( VP ( VB ) ( NP ( PRP ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# ah well then , do n't sign it !
#
# . 's on
#
# --
#
# ROOT ( S ( VP ( VB ) ( VP ( VB ) ( PRT ( RP ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# write dat down !
#
#
#
# --
#
# ROOT ( S ( INTJ ( UH ) ) ( , ) ( VP ( VB ) ( RB ) ( VP ( VB ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# yeah , do n't worry .
#
# i
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBP ) ( FW ) ( FW ) ( VP ( VBP ) ( S ( VP ( TO ) ( VP ( VB ) ( NP ( DT ) ( NN ) ) ) ) ) ( SBAR ( IN ) ( S ( NP ( NN ) ) ( VP ( VBZ ) ( RB ) ( VP ( VB ) ( PRT ( RP ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# we 're gon na have to breach the building if skinner does n't come up with the money .
#
#
#
# --
#
# ROOT ( NP ( LST ( -LRB- ) ( `` ) ) ( RB ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( , ) ( INTJ ( UH ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# `` not at this hour , sir .
#
#
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBZ ) ( NP ( NP ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( JJ ) ( NN ) ) ) ( PP ( IN ) ( NP ( JJR ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# it 's din@@ ner@@ time on the east coast in less than an hour .
#
#
#
# --
#
# ROOT ( SQ ( CC ) ( NP ( PRP ) ) ( VP ( `` ) ( VP ( VBP ) ( RB ) ( VP ( NP ( FW ) ( FW ) ) ( VP ( VB ) ( NP ( DT ) ) ) ) ) ) ( , ) ( VBP ) ( NP ( PRP ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# but i 'm not gon na do that , am i ?
#
#
#
# --
#
# ROOT ( S ( NP ( NN ) ) ( VP ( VBD ) ( RB ) ( ADVP ( RB ) ) ( NP ( DT ) ( NN ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# sex was n't really an issue .
#
# . .
#
# --
#
# ROOT ( NP ( NP ( NN ) ( CD ) ) ( NP ( NP ( NNS ) ) ( CC ) ( NP ( NP ( NNS ) ) ( PP ( IN ) ( NP ( NN ) ( CD ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# article 226 modifications and rec@@ ti@@ fications of coverage 1 .
#
# the the
#
# --
#
# ROOT ( S ( VP ( VB ) ( RB ) ( VP ( VB ) ( PP ( IN ) ( NP ( PRP ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# do n't argue with me .
#
#
#
# --
#
# ROOT ( S ( NP ( NN ) ) ( : ) ( NP ( FW ) ) ( , ) ( VP ( VB ) ( PRT ( RP ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# otis - otis , wake up !
#
#
#
# --
#
# ROOT ( S ( NP ( DT ) ) ( VP ( VBZ ) ( NP ( NP ( NN ) ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ( NN ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# this is rain@@ er bau@@ mann from the film festival .
#
#
#
# --
#
# ROOT ( S ( VP ( VB ) ( NP ( PRP ) ) ( PP ( IN ) ( NP ( NP ( PRP ) ) ( , ) ( NP ( NN ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# give it to her , captain .
#
# 's that .
#
# --
#
# ROOT ( S ( CC ) ( NP ( PRP ) ) ( VP ( VBP ) ( NP ( NP ( DT ) ( NN ) ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBZ ) ) ) ) ) ) ( . ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# and you believe every word he says ? .
#
#
#
# --
#
# ROOT ( S ( S ( NP ( DT ) ( VBN ) ( NN ) ) ( VP ( VBD ) ( VP ( VBN ) ( , ) ( S ( VP ( VBG ) ( NP ( NP ( DT ) ( NN ) ) ( PP ( IN ) ( NP ( PRP$ ) ( NNS ) ) ) ) ) ) ) ) ) ( , ) ( CC ) ( S ( S ( NP ( DT ) ( NN ) ) ( VP ( VBD ) ( VP ( VBN ) ( ADVP ( RB ) ) ) ) ) ( CC ) ( S ( NP ( NNP ) ) ( VP ( VBD ) ( ADJP ( JJ ) ( PP ( IN ) ( NP ( PRP ) ) ) ) ) ) ) ( . ) ) )
#
# the undermined wall had collapsed , killing a score of his men , but the rest had re@@ grouped well and mic@@ han@@ ek was proud of them .
#
# i ,
#
# --
#
# ROOT ( S ( NP ( EX ) ) ( VP ( VBZ ) ( NP ( NP ( JJ ) ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( S ( VP ( TO ) ( VP ( VB ) ( PRT ( RP ) ) ( NP ( NP ( NN ) ) ( SBAR ( WHNP ( WDT ) ) ( S ( VP ( MD ) ( VP ( VB ) ( ADVP ( RB ) ) ) ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# there 's enough fuel in this thing to wipe out anything that might come back .
#
# the
#
# --
#
# ROOT ( S ( -LRB- ) ( `` ) ( ADVP ( RB ) ) ( , ) ( INTJ ( UH ) ) ( , ) ( '' ) ( NP ( FW ) ) ( VP ( VBD ) ( , ) ( S ( VP ( VP ( VBG ) ( ADVP ( ADVP ( RB ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ) ( CC ) ( VP ( VBG ) ( PRT ( RP ) ) ( NP ( DT ) ( JJ ) ( NN ) ( NN ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# `` here , boy , '' sadi offered , coming back into the light and holding out a brown earth@@ en@@ ware cup .
#
# ,
#
# --
#
# ROOT ( FRAG ( ADJP ( RBR ) ) ( S ( VP ( TO ) ( VP ( VB ) ( S ( NP ( PRP ) ) ( VP ( VB ) ( NP ( DT ) ( JJ ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# better to let them destroy each other .
#
# . . .
#
# --
#
# ROOT ( S ( S ( NP ( PRP ) ) ( VP ( VBP ) ( S ( VP ( TO ) ( VP ( VB ) ( NP ( DT ) ) ) ) ) ) ) ( : ) ( CC ) ( S ( NP ( PRP$ ) ( JJ ) ( NN ) ) ( VP ( VBZ ) ( NP ( NP ( DT ) ( NN ) ) ( PP ( IN ) ( NP ( NP ( DT ) ( NNS ) ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBP ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# we try to prevent th@@ is-@@ but your own case is an example of the problems we encounter .
#
#
#
# --
#
# ROOT ( S ( IN ) ( NP ( DT ) ) ( VP ( VBZ ) ( PP ( IN ) ( NP ( NP ( DT ) ( NN ) ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBP ) ( PP ( IN ) ( NP ( NP ( DT ) ( NN ) ) ( PP ( IN ) ( NP ( NP ( DT ) ( NN ) ) ( SBAR ( WHNP ( WDT ) ) ( S ( VP ( VBZ ) ( NP ( JJ ) ( NN ) ) ) ) ) ) ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# so that 's like the dust they sweep off the floor of a place that makes real cheese .
#
# did it
#
# --
#
# ROOT ( S ( INTJ ( RB ) ) ( : ) ( S ( NP ( PRP ) ) ( VP ( VBZ ) ( RB ) ( NP ( ADJP ( NN ) ( <unk> ) ( JJ ) ) ( JJ ) ( NN ) ) ) ) ( , ) ( CC ) ( S ( NP ( PRP ) ) ( VP ( VBZ ) ( RB ) ( VP ( VB ) ( ADJP ( RB ) ( <unk> ) ( JJ ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# well ... it is n't line-@@ caught blue mar@@ lin , but it does n't look half-@@ bad .
#
#
#
# --
#
# ROOT ( NP ( PDT ) ( DT ) ( JJ ) ( NN ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# all the same deno@@ mination ?
#
# the ,
#
# --
#
# ROOT ( SBARQ ( CC ) ( , ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( , ) ( SBAR ( IN ) ( S ( NP ( PDT ) ( DT ) ) ( VP ( VBZ ) ( VP ( VBG ) ( PRT ( RP ) ) ) ) ) ) ( , ) ( WHADVP ( WRB ) ) ( S ( NP ( DT ) ( NN ) ) ( VP ( VBZ ) ( NP ( PRP$ ) ( NN ) ) ) ) ( , ) ( SBAR ( IN ) ( S ( NP ( EX ) ) ( VP ( VBZ ) ( NP ( DT ) ( NN ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# and , by the way , while all this is going on , where the hell is your boss , if there is a god ?
#
#
#
# --
#
# ROOT ( S ( SBAR ( IN ) ( S ( NP ( NN ) ) ( VP ( VBD ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBD ) ( NP ( PRP ) ) ) ) ) ) ) ) ( , ) ( WHNP ( WP ) ) ( S ( VP ( VBZ ) ( SBAR ( WHADVP ( WRB ) ) ( S ( NP ( PRP ) ) ( VP ( MD ) ( VP ( VB ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# if someone said they suspected him , who knows how she 'd react .
#
#
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBZ ) ( RB ) ( NP ( NP ( DT ) ( JJ ) ( NN ) ) ( SBAR ( S ( VP ( TO ) ( VP ( VB ) ( SBAR ( S ( NP ( PRP ) ) ( ADJP ( JJ ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# he is not the first roman to believe himself capable of the act .
#
#
#
# --
#
# ROOT ( ADVP ( RB ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# almost . i 've just got to ... want it .
#
#
#
# --
#
# epoch : 5
# epoch : 10
# epoch : 15
# epoch : 20
# epoch : 25
# epoch : 30
# ROOT ( INTJ ( UH ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# yeah ? -@@ hey ty ... ... give me that guy 's number .
#
# ,
#
# --
#
# ROOT ( FRAG ( INTJ ( UH ) ) ( , ) ( NP ( UH ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# hi , cu@@ tie !
#
# . i , ,
#
# --
#
# ROOT ( S ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( , ) ( NP ( PRP ) ) ( VP ( VBD ) ( NP ( PRP$ ) ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( JJ ) ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# along the way , i threw my gun into the royal river . i 've been very clear on this point .
#
#
#
# --
#
# ROOT ( S ( SBAR ( IN ) ( S ( NP ( PRP ) ) ( VP ( -LRB- ) ( VP ( VBP ) ( VP ( VBG ) ( NP ( PRP$ ) ( NN ) ) ) ) ) ) ) ( , ) ( S ( NP ( PRP ) ) ( VP ( VBP ) ( S ( VP ( TO ) ( VP ( VB ) ( PP ( IN ) ( NP ( NN ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# co@@ z i 'm changing your punishment , you have to play with erik !
#
# ,
#
# --
#
# ROOT ( FRAG ( INTJ ( UH ) ) ( , ) ( UH ) ( NP ( DT ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# yeah , roger that .
#
# ,
#
# --
#
# ROOT ( S ( VP ( VBG ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# looking for that reward ?
#
# . i . . , ,
#
# --
#
# ROOT ( S ( S ( VP ( VBG ) ( SBAR ( WHNP ( WP ) ) ( S ( NP ( PRP ) ) ( VP ( VBD ) ( PP ( IN ) ( NP ( PRP ) ) ) ) ) ) ) ) ( , ) ( S ( VP ( VBG ) ( ADJP ( JJ ) ( S ( VP ( TO ) ( VP ( VB ) ( NP ( PRP ) ) ) ) ) ) ) ) ( VP ( VBZ ) ( NP ( NP ( FW ) ( FW ) ) ( VP ( VB ) ( NP ( DT ) ( JJ ) ( NN ) ) ) ) ) ( . ) ) )
#
# considering what you did to us , being able to find you is gon na go a long way .
#
# you . to
#
# --
#
# ROOT ( S ( -LRB- ) ( '' ) ( NP ( PRP ) ) ( VP ( VBP ) ( VP ( VBN ) ( NP ( DT ) ( JJ ) ( NN ) ) ( PP ( IN ) ( NP ( PRP$ ) ) ) ) ) ( : ) ( '' ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# `` you have endangered the entire colony by your stupi@@ dit@@ y@@ - ''
#
# .
#
# --
#
# ROOT ( S ( NP ( PRP$ ) ( JJ ) ( NN ) ) ( VP ( VBZ ) ( NP ( PRP$ ) ( NN ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# your key fo@@ b is your friend .
#
#
#
# --
#
# ROOT ( S ( NP ( NN ) ) ( VP ( VBD ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# paul exclaimed .
#
# . .
#
# --
#
# ROOT ( S ( S ( NP ( DT ) ( NN ) ) ( , ) ( S ( VP ( VBG ) ( NP ( PRP$ ) ( JJ ) ( NN ) ) ) ) ) ( , ) ( NP ( PRP ) ) ( VP ( VBP ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# the bo@@ at@@ shed , charming our dea agent , we hope .
#
# .
#
# --
#
# ROOT ( S ( NP ( DT ) ( NN ) ) ( VP ( VBZ ) ( VP ( VBN ) ( SBAR ( IN ) ( S ( NP ( PRP ) ) ( VP ( VBZ ) ( ADJP ( VBN ) ( S ( VP ( TO ) ( VP ( VB ) ( NP ( NN ) ( NN ) ) ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# no one has questioned that he is qualified to be vice president .
#
# n't was to
#
# --
#
# ROOT ( S ( CC ) ( NP ( NP ( NP ( NN ) ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBZ ) ) ) ) ) ( , ) ( INTJ ( UH ) ) ( , ) ) ( VP ( VBZ ) ( ADJP ( JJ ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# and everything he does , huh , is big .
#
# , the the .
#
# --
#
# ROOT ( S ( NP ( NN ) ) ( VP ( MD ) ( VP ( VB ) ( NP ( DT ) ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# god will provide a way .
#
# . . the
#
# --
#
# ROOT ( S ( VP ( VB ) ( NP ( NP ( FW ) ) ( : ) ( NP ( FW ) ( FW ) ( NN ) ) ) ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# recommend or@@ ti@@ sei - val garden@@ a web@@ cam
#
#
#
# --
#
# ROOT ( S ( VP ( VBD ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBD ) ( VP ( VBG ) ( S ( VP ( VBG ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# thought we were going shooting .
#
# . .
#
# --
#
# ROOT ( S ( NP ( EX ) ) ( VP ( VBP ) ( NP ( NP ( DT ) ( NNS ) ) ( CC ) ( NP ( DT ) ( NN ) ( NN ) ) ) ( IN ) ( ADVP ( RB ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# there are a gps and a voice mic inside here .
#
# , ,
#
# --
#
# ROOT ( S ( NP ( NP ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( JJ ) ( NNS ) ) ) ) ( VP ( VP ( VBD ) ( ADVP ( RB ) ) ) ( CC ) ( VP ( VBD ) ( PP ( IN ) ( NP ( DT ) ( JJ ) ( NN ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# none of the large retailers came forward and cooperated in the present investigation .
#
#
#
# --
#
# ROOT ( S ( S ( NP ( NP ( NNS ) ) ( PP ( IN ) ( NP ( NNS ) ( CD ) ( NN ) ( CD ) ) ) ) ( VP ( VBZ ) ( VP ( VBN ) ) ) ) ( CC ) ( S ( NP ( NNS ) ( CD ) ( CC ) ( CD ) ) ( VP ( VBP ) ( VP ( VBN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# amendments to ifrs 7 paragraph 12 is amended and paragraphs 12@@ a and 44@@ e are added .
#
# ,
#
# --
#
# ROOT ( S ( S ( NP ( PRP ) ) ( VP ( VBD ) ( PRT ( RP ) ) ( NP ( JJ ) ( NN ) ) ) ) ( , ) ( CC ) ( S ( NP ( DT ) ( JJ ) ( , ) ( ADJP ( RB ) ( JJ ) ) ( NN ) ) ( VP ( VBD ) ( VP ( VBN ) ( PP ( IN ) ( NP ( CD ) ( NNS ) ) ) ( PP ( IN ) ( NP ( DT ) ( JJ ) ( NN ) ( NN ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# they fired in neat unison , and the small , nearly por@@ tly figure was thrown across two lanes like a limp laundry sack .
#
# i i to . and
#
# --
#
# ROOT ( SBARQ ( WHADVP ( WRB ) ) ( IN ) ( NP ( NP ( DT ) ( NN ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( ADVP ( RB ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# how about a beer in a bottle instead ?
#
# .
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBD ) ( ADJP ( FW ) ( FW ) ( VB ) ( ADJP ( JJ ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# i was gon na say amazing .
#
#
#
# --
#
# ROOT ( S ( S ( NP ( PRP ) ) ( VP ( VBD ) ( VP ( VBN ) ( PRT ( RP ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ( PP ( IN ) ( NP ( NP ( DT ) ( NN ) ) ( ADVP ( IN ) ) ) ) ) ) ) ( , ) ( CC ) ( S ( NP ( DT ) ( NN ) ) ( VP ( VBD ) ( ADJP ( JJ ) ( CC ) ( JJ ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# they were cut off from the wind by the ridge behind , and the air was still and stuffy .
#
# .
#
# --
#
# ROOT ( S ( NP ( NP ( NNS ) ) ( VP ( VBG ) ( NP ( DT ) ( CD ) ( FW ) ( NN ) ) ) ) ( VP ( VBD ) ( ADJP ( JJ ) ( PP ( IN ) ( NP ( NP ( NN ) ) ( PP ( IN ) ( NP ( NP ( NP ( NN ) ( NNS ) ) ( NP ( QP ( CD ) ( <unk> ) ( RB ) ) ( DT ) ) ) ( PP ( IN ) ( NP ( <unk> ( JJ ) ( <unk> ) ( NN ) ) ( NN ) ) ) ) ) ) ) ) ) ( . ) ) )
#
# viruses containing the r@@ ta@@ 18@@ 1@@ t mutation remained susceptible to teno@@ fo@@ vir with ec@@ 50 values 1.@@ 5-@@ fold that of wil@@ d-@@ type virus .
#
# to
#
# --
#
# ROOT ( FRAG ( ADVP ( RB ) ) ( , ) ( S ( VP ( VBG ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( MD ) ( VP ( VB ) ( SBAR ( IN ) ( S ( NP ( NN ) ) ( VP ( MD ) ( VP ( VB ) ( NP ( NN ) ) ( PP ( IN ) ( NP ( PRP$ ) ( NN ) ) ) ) ) ) ) ) ) ) ) ) ) ( : ) ( : ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# well , assuming we can prove that seth can manipulate metal with his mind ... ... what does that have to do with@@ lana 's sudden seth inf@@ at@@ uation ?
#
# it
#
# --
#
# ROOT ( S ( CC ) ( NP ( PRP ) ) ( VP ( VBZ ) ( NP ( NN ) ) ( PP ( IN ) ( NP ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# and it puts everybody in jeopardy . pretty big stakes .
#
# it
#
# --
#
# ROOT ( S ( INTJ ( UH ) ) ( , ) ( NP ( DT ) ( NN ) ( NN ) ) ( VP ( VBZ ) ( ADJP ( JJ ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# ooh , that piano player is cute as a bug .
#
# , ? . .
#
# --
#
# ROOT ( S ( NP ( NP ( PRP ) ) ) ( VP ( VBZ ) ( NP ( PRP ) ) ( NP ( QP ( RB ) ( RB ) ( CD ) ) ( NNS ) ) ( S ( VP ( TO ) ( VP ( VB ) ( S ( VP ( TO ) ( VP ( VB ) ( PP ( IN ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# it takes us just about five minutes to decide to stay on .
#
#
#
# --
#
# ROOT ( S ( NP ( EX ) ) ( VP ( VBP ) ( NP ( NP ( NP ( NNS ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ) ) ) ( SBAR ( WHNP ( WP ) ) ( S ( VP ( VBP ) ( NP ( NN ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# there are people in the world who love beauty .
#
# i
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( ADVP ( RB ) ) ( VP ( VBP ) ( S ( VP ( TO ) ( VP ( VB ) ( ADVP ( RB ) ( SBAR ( WHADVP ( WRB ) ) ( S ( NP ( NN ) ) ( VP ( VBZ ) ( NP ( NP ( PRP ) ) ( CC ) ( SBAR ( WHNP ( WP ) ) ( S ( NP ( PRP ) ) ( VP ( VBD ) ) ) ) ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# i just want to go somewhere where nobody knows me or what i did .
#
#
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( `` ) ( VP ( VBP ) ( VP ( VBG ) ( ADVP ( RB ) ( PP ( IN ) ( NP ( NN ) ( NNP ) ) ) ) ( ADVP ( RB ) ) ) ) ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# i 'm coming back to hong kong now
#
#
#
# --
#
# ROOT ( NP ( NP ( NNS ) ) ( PP ( IN ) ( NP ( NN ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# problems with alma ? - ugh .
#
#
#
# --
#
# epoch : 5
# epoch : 10
# epoch : 15
# epoch : 20
# epoch : 25
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBD ) ( VP ( VBG ) ( SBAR ( S ( ADVP ( RB ) ) ( NP ( PRP ) ) ( VP ( MD ) ( VP ( VB ) ( NP ( DT ) ( JJ ) ) ( PP ( IN ) ( NP ( DT ) ( JJ ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# i was thinking maybe we could do some good for each other .
#
# with . a , ,
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBZ ) ( NP ( <unk> ( NN ) ( NN ) ) ( NN ) ) ( PP ( IN ) ( NP ( NN ) ) ) ( PP ( IN ) ( : ) ( NP ( NP ( ADJP ( RB ) ( JJ ) ) ( NNS ) ) ( PP ( IN ) ( NP ( DT ) ( NN ) ( NN ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# he has cell phone footage of jonathan with ... very young men at the lake house .
#
#
#
# --
#
# ROOT ( S ( -LRB- ) ( '' ) ( NP ( DT ) ) ( VP ( VBZ ) ( SBAR ( WHNP ( WP ) ) ( S ( NP ( PRP ) ) ( VP ( MD ) ( VP ( VB ) ( SBAR ( WHADVP ( WRB ) ) ( S ( NP ( PRP ) ) ( VP ( VBP ) ( ADVP ( RB ) ) ) ) ) ) ) ) ) ) ( . ) ( '' ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# `` this is what they 'll remember when they look back . ''
#
#
#
# --
#
# ROOT ( S ( NP ( PRP ) ) ( VP ( VBP ) ( NP ( NN ) ) ( SBAR ( IN ) ( S ( NP ( PRP ) ) ( VP ( VBP ) ( PP ( IN ) ( NP ( NN ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# they find rest as they lie in death .
#
# . , i .
#
# --
#
# ROOT ( S ( S ( NP ( PRP$ ) ( JJ ) ( NN ) ) ( VP ( VBD ) ( VP ( VBZ ) ( VP ( VBG ) ( PP ( IN ) ( NP ( PRP ) ) ) ) ) ) ) ( , ) ( CC ) ( S ( NP ( PRP ) ) ( VP ( VBD ) ( NP ( DT ) ( JJ ) ( NN ) ( NN ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# my little brother ed 's standing behind you , and he got a regular navy pistol .
#
# .
#
# --
#
# ROOT ( FRAG ( ADJP ( JJ ) ) ( , ) ( ADVP ( RB ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# shameful , indeed .
#
# .
#
# --
#
# ROOT ( ADJP ( JJ ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# dead .
#
# the in
#
# --
#
# ROOT ( S ( NP ( NP ( PRP ) ) ( `` ) ) ( VP ( VBP ) ( ADVP ( RB ) ) ( RB ) ( VP ( VBG ) ( SBAR ( WHADVP ( WRB ) ) ( S ( NP ( PRP ) ) ( VP ( VBP ) ( ADJP ( VBN ) ( PP ( IN ) ( NP ( DT ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# i 'm still not getting why we 're involved with this .
#
# you
#
# --
#
# ...
#
# annex no 7@@ 6/@@ t@@ q@@ 40 member state spain stock red@@ /@@ 5@@ 12@@ 14@@ d .
#
# the . and ,
#
# --
#
# ROOT ( SBAR ( IN ) ( S ( NP ( PRP ) ) ( VP ( VBP ) ( VP ( VBG ) ( PRT ( RP ) ) ( PP ( IN ) ( NP ( NP ( NN ) ) ( SBAR ( S ( NP ( PRP ) ) ( VP ( VBP ) ( RB ) ( VP ( VB ) ) ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# if you 're sitting down with someone you do n't trust .
#
# and i on
#
# --
#
# ROOT ( S ( VP ( VB ) ( NP ( NN ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# take girl ! go !
#
# .
#
# --
#
# ROOT ( S ( VP ( PRP ) ( VP ( VB ) ( ADVP ( RB ) ( RB ) ) ( ADVP ( RB ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# he'il be back home soon .
#
# .
#
# --
#
# ROOT ( S ( VP ( VP ( VB ) ( ADVP ( RB ) ) ) ( , ) ( VP ( VB ) ( NP ( DT ) ( JJ ) ( NN ) ) ) ( : ) ( CC ) ( VP ( VB ) ( S ( VP ( VBG ) ( PP ( IN ) ( NP ( NP ( JJ ) ( NNS ) ) ( CC ) ( NP ( NN ) ) ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# go home , take a hot bath ... and start looking into technical colleges or co@@ sme@@ to@@ logy .
#
#
#
# --
#
# ROOT ( FRAG ( S ( VP ( TO ) ( VP ( VB ) ( NP ( PRP$ ) ( NN ) ) ( ADVP ( RB ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# to get my son back .
#
# .
#
# --
#
# ROOT ( NP ( CC ) ( NP ( JJ ) ( NNS ) ) ( : ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# or demographic handi@@ caps ;
#
# ,
#
# --
#
# ROOT ( NP ( LS ) ( '' ) ( PP ( IN ) ( NP ( PRP$ ) ( NN ) ) ) ( IN ) ( NP ( DT ) ( FW ) ( . ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# `` in my family for a . . . very long time . ''
#
# . the . . . it the
#
# --
#
# ROOT ( S ( NP ( DT ) ( NN ) ( NNS ) ) ( VP ( VBP ) ( NP ( NN ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# the conference finals are saturday .
#
# . a .
#
# --
#
# ROOT ( S ( CC ) ( S ( NP ( PRP ) ) ( VP ( VBD ) ) ) ( CC ) ( S ( NP ( PRP ) ) ( VP ( VBD ) ( NP ( PRP$ ) ( RB ) ) ( PP ( IN ) ( NP ( DT ) ( NNS ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# but you fled and you turned your back on those gifts .
#
# the
#
# --
#
# ROOT ( S ( VP ( VB ) ( S ( NP ( PRP ) ) ( ADVP ( RB ) ) ( VP ( VB ) ( NP ( NP ( DT ) ( JJ ) ( NN ) ) ( , ) ( NP ( DT ) ( NN ) ) ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# let 's just get a me@@ sc@@ lu@@ n salad , no pepper . just very simple .
#
#
#
# --
#
# ROOT ( SQ ( MD ) ( NP ( PRP ) ) ( VP ( VB ) ( NP ( PRP ) ) ( VP ( VB ) ( NP ( PRP$ ) ( NN ) ) ( ADVP ( RB ) ) ) ) ( . ) ) ) <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
#
# would you let me read your book sometime ?
#
#
#
# --
#
# epoch : 5
# epoch : 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /root/projects/NLP_projects/synpg/inference_synpg.ipynb Cell 12 in 1
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> generate(model, valid_dataloader, criterion, val_loader_length, syndict)
#
# /root/projects/NLP_projects/synpg/inference_synpg.ipynb Cell 12 in 1
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> max_synt_len = synts_.size(1) - 2  # count without <sos> and <eos>
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> # generate
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> idxs = model.generate(sents_, synts_, sents_.size(1), temp=0.5)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> # write output
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> for sent, idx, synt in zip(sents_.cpu().numpy(), idxs.cpu().numpy(), synts_.cpu().numpy()):
#
# /root/projects/NLP_projects/synpg/inference_synpg.ipynb Cell 12 in 1
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=123'>124</a>     print(f'epoch : {i}')
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=124'>125</a> # decode
# --> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=125'>126</a> outputs = self.transformer.decoder(de_embeddings, memory, tgt_mask=trg_mask)
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=126'>127</a> outputs = self.linear(outputs[-1].contiguous().view(-1, self.emb_dim))
#     <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f64617461736369656e6365646f636b6572656e762d6d61696e2d707974686f6e2d31227d/root/projects/NLP_projects/synpg/inference_synpg.ipynb#W6sdnNjb2RlLXJlbW90ZQ%3D%3D?line=128'>129</a> # get argmax index or sample index
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:333, in TransformerDecoder.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask)
#     330 output = tgt
#     332 for mod in self.layers:
# --> 333     output = mod(output, memory, tgt_mask=tgt_mask,
#     334                  memory_mask=memory_mask,
#     335                  tgt_key_padding_mask=tgt_key_padding_mask,
#     336                  memory_key_padding_mask=memory_key_padding_mask)
#     338 if self.norm is not None:
#     339     output = self.norm(output)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:653, in TransformerDecoderLayer.forward(self, tgt, memory, tgt_mask, memory_mask, tgt_key_padding_mask, memory_key_padding_mask)
#     651     x = self.norm1(x + self._sa_block(x, tgt_mask, tgt_key_padding_mask))
#     652     x = self.norm2(x + self._mha_block(x, memory, memory_mask, memory_key_padding_mask))
# --> 653     x = self.norm3(x + self._ff_block(x))
#     655 return x
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:677, in TransformerDecoderLayer._ff_block(self, x)
#     676 def _ff_block(self, x: Tensor) -> Tensor:
# --> 677     x = self.linear2(self.dropout(self.activation(self.linear1(x))))
#     678     return self.dropout3(x)
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
