# %%
# import pickle
# with open("./data/nmt_dataset_100000.pkl", "rb") as file:
#     nmt_dataset_100000 = pickle.load(file)

# with open("./data/nmt_dataset_100000_600000.pkl", "rb") as file:
#     nmt_dataset_100000_600000 = pickle.load(file)

# %%
# len(nmt_dataset_100000),len(nmt_dataset_100000_600000)
# Out:
# (100000, 500000)

# %%
# nmt_dataset_600000 = nmt_dataset_100000+nmt_dataset_100000_600000

# %%
# with open('./data/nmt_dataset_600000.pkl', 'wb') as f:
#     pickle.dump(nmt_dataset_600000, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle
with open("./data/qq_dataset_300000.pkl", "rb") as file:
    qq_dataset_300000 = pickle.load(file)

with open("./data/qq_dataset_300000_1000000.pkl", "rb") as file:
    qq_dataset_300000_1000000 = pickle.load(file)

# %%
len(qq_dataset_300000),len(qq_dataset_300000_1000000)
# Out:
# (300000, 700000)

# %%
qq_dataset_1000000 = qq_dataset_300000+qq_dataset_300000_1000000
len(qq_dataset_1000000)
# Out:
# 1000000

# %%
with open('./data/qq_dataset_1m.pkl', 'wb') as f:
    pickle.dump(qq_dataset_1000000, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle
with open("./data/qq_dataset_1m.pkl", "rb") as file:
    qq_dataset_1m = pickle.load(file)
qq_dataset_1m[:5]
# Out:
# [([21396,
#    2501,
#    146,
#    111,
#    398,
#    12594,
#    10642,
#    3,
#    12204,
#    6087,
#    16438,
#    3,
#    126,
#    956,
#    3310,
#    4522,
#    119],
#   [106,
#    6,
#    106,
#    62,
#    106,
#    84,
#    106,
#    86,
#    107,
#    107,
#    106,
#    65,
#    106,
#    80,
#    106,
#    77,
#    107,
#    106,
#    41,
#    106,
#    41,
#    106,
#    17,
#    107,
#    106,
#    28,
#    107,
#    106,
#    37,
#    107,
#    107,
#    106,
#    61,
#    106,
#    60,
#    106,
#    41,
#    106,
#    41,
#    106,
#    36,
#    107,
#    107,
#    106,
#    98,
#    107,
#    106,
#    7,
#    106,
#    9,
#    106,
#    55,
#    107,
#    107,
#    106,
#    26,
#    107,
#    107,
#    106,
#    99,
#    107,
#    107,
#    106,
#    45,
#    106,
#    24,
#    107,
#    106,
#    41,
#    106,
#    36,
#    107,
#    106,
#    36,
#    107,
#    107,
#    107,
#    107,
#    107,
#    107,
#    107,
#    107,
#    106,
#    94,
#    107,
# ...
