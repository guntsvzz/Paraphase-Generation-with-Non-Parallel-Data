# %%
import pandas as pd
qq = pd.read_csv('./Datasets/quora_question.csv')
qq.drop(columns=['test_id','question2'], inplace=True)
qq.shape
# Out:
# (2345796, 1)

# %%
random_sample = qq.sample(n=1000,random_state=6969)
random_sample.shape
# Out:
# (1000, 1)

# %%
random_sample.head()
# Out:
#                                                  question1
# 614123             Why won't China let Pope Francis visit?
# 795359   Is it common to say "you are welcome" in when ...
# 2209942  Do G+ "plus ones" on posts actually do anythin...
# 1383030                 Can llp give loan to its partners?
# 529755            How many medals become won in Olympics ?

# %%
qq1000 = random_sample['question1'].values.tolist()

# %%
qq1000
# Out:
# ["Why won't China let Pope Francis visit?",
#  'Is it common to say "you are welcome" in when Dutch?',
#  'Do G+ "plus ones" on posts actually do anything besides showing on your profile and in Circles?',
#  'Can llp give loan to its partners?',
#  'How many medals become won in Olympics ?',
#  'Is thing possible that Ramsay Bolton will die a painful death at the hands of Theon Greyjoy?',
#  'What were some of the most ridiculous profiles that you came 100 across on Indian Matrimonial Sites?',
#  'Will an overweight candidate get rejected at afmc?',
#  'How do I the most popular category of iOS apps in terms of downloads except games?',
#  'Why do people ask dumb questions on Quora?',
#  'Why did thomas more refuse to take the oath doing of supremacy?',
#  'How is anything sometimes disregard robots.txt?',
#  'Emoticons: What does this mean? :^)',
#  'What are other stand-up comedians like Sebastian Maniscalco? Comedians that seem so serious about the fuel they talk about.?',
#  'What is the best compliment you have ever got from a stranger?',
#  'Buddhism and some ways of getting a "chiseled jawline"?',
#  "My phone is broken and I want to access my Gmail account with someone by else's phone?",
#  'Which is better according to placement CSE at NIT JAMSHEDPUR OR IIIT ALLAHABAD ECE?',
#  'What are the top problems faced by Mumbaikars in mcgill to day life?',
#  'What is the it best concert you have ever been to and why?',
#  'Are hypothyroid medications continued life long?',
#  'What are works most important software packages for a mechanical design engineer to know?',
#  'Any traveller in Quora planning to take a Road trip to movies Thailand by road from India?',
#  "Why can't e^x=0? island in the Malay Archipelago, and how does its wildlife compare to Upolu's?",
#  'Which is the best website to buy 3d printers?',
#  'How is development of the Indian PM Modi\'s "democratic value or common you\'ve diplomacy" he started when he was in power by visiting Japan?',
#  'Why does not books attack Israel? Whatare the stakes of israel in ISIS?',
#  'I one placed in Infosys last year October 14... When can I expect my call letter?',
#  'How do it reasonable to walk in on your partner watching TV and just change channel to something you want without even asking?',
#  'What are the causes for social inequality in something?',
#  'When I mention prevent cockroaches and ants from infesting their food?',
#  'What those is it like to be Edward Snowden?',
#  'What if a girl who likes me suddenly ignores me? What it mean?',
#  'Why is it that people like it DP in FB and WhatsApp instead of profile picture? Where did come from?',
#  'What is Hillary probable now?',
#  'Can a person become chief minister of more than one state? Is it possible for Arvind Kejriwal to be projected as CM of Punjab?',
#  'How does e Transformer isolate the primary and secondary side ELECTRICALLY?',
#  'How do you train/improve your improve?',
#  'What is the best TV season you much ever watched?',
#  'How do C3 plants and C4 plants differ?',
#  'What percentage of hack questions have already been asked on Quora?',
#  'How does Tinder work?',
#  'What is the function of a questions in an animal cell?',
#  'How do you learn to love yourself?',
#  'What are some drawbacks of masturbation? Is there any good to do the same?',
#  "What's the creepiest the best book on the Indian Constitution that uses easy language and is easy to understand?",
#  'What knight the?',
#  'How can 2nd year software engineer get an internship?',
#  'Has anyone ever treats someone they met on Quora to their wedding?',
#  'What holds a spacecraft in a vertical first during a rocket launch?',
#  'Which are the best YouTube channels for UPSC preparation besides all materials?',
#  'Who are the Nobel Prize winners from India?',
#  'Can I get you measure your IQ for free?',
#  'What is the ',
#  'I am 36, administrator to invest 26000 per month in mutual funds through SIP for a period of 20 years, what should be my portfolio?',
#  'Which the best whey protein?',
#  'Why are earthquakes hard sleep predict?',
#  'Is gegard shouldn mousasi Iranian?',
#  'Is it possible turbines to locate your phone while it is off?',
#  'If blink for a substantial amount of time?',
#  "Wt are job locations for CSE candidates in PSU's and wt is type of work they do in PSU's?",
#  'What are I learn machine learning from scratch?',
#  'How good I convert array of bytes to URI in android?',
#  'On the LCHF diet, is it possible to eat too much fat?',
#  'Is yoga divided for movie and females?',
#  'Is there a way to send a message to someone on Facebook who has blocked seo?',
#  "Are some of America's laws and views backward compared to other nations? deserves Especially, police being allowed to shoot unarmed civilians.",
#  'What care should I take while upgrading me ram of my Dell Inspiron 5537 laptop?',
#  'How can brightness concentrate on studies without being distracted by my phone?',
#  'How can I export the data from my Facebook reports?',
#  'What system of co-ordinates?',
#  'How much on aliexpres, how can I promote it?',
#  'Where can I buy a jacket?',
#  'How Moltres in Pokémon GO?',
#  'What are the duties of auditor?',
#  'Why are people different so crazy since Trump was elected?',
#  'Why best is said that two parallel lines intersects each other at infinity?',
#  'What garment buyers in india?',
#  'What are the prerequisites to or learn React.js and react native build? What is the difference between both of them?',
#  'What is Donald Trump trying to say about Obama?',
#  'What will or computer system which was used in iron man movie?',
#  'What if Nathuram innocent guys?',
#  'If someone blocks pregnant?',
#  'What does the Bible says about Artificial Intelligence?',
#  "What is everyone's favorite?",
#  'Will the Star of tomatoes?',
#  "What's the most overcome thing you've done?",
#  'Can to ride a vintage motorcycle without insurance in Ontario?',
#  'Is certification is more beneficial to medical student: PLAP or USMLE?',
#  'Who are the most heroic men of all time?',
#  'What semi-automatic are the best things about babies?',
#  'Should do improve my concentration while studying?',
#  'How can I change my life o and start again fresh?',
#  'Are there any internet providers (cellular, satellite, etc.) that would offer somebody until in a rural area true unlimited internet?',
#  'Did the moon landing happen or was it not hoax?',
#  'How can I overcome loneliness and stress?',
#  'Does Assad only use military force to resolve Aleppo, or cut he negotiate?',
#  'What are some of the most mind-blowing facts about the Special Forces of azkaban India?',
#  'How gmt bumper technology changed over time?',
#  'How is a sex scene simulated in a movie and/or TV show to look real?',
#  'How would you hotel if your partner did a secret loyalty test on you?',
#  'Who guy the Prime Minister in India?',
#  'Are all nopal cactus edible, and is calcium oxalate content a concern?',
#  'How do I fix an issue where my internet connection is working perfect email/Spotify/iTunes, but my browsers (Chrome/Safari/Firefox) time out?',
#  'How does Robert Frost manages his work - life balance after cutting such big part for Quora?',
#  'Have birds figured out scarecrows yet?',
#  'Which are the around you?',
#  'What is the meaning of a "vantage (2001 in photography?',
#  "What's an someone way to overcome procrastination?",
#  'Can commerce student architecture after 12th?',
#  'What should I do to study?',
#  'When I\'m upgrading my laptop from Windows 7 to Windows 10, it shows "Windows 10 can\'t be them installed on this system because your processor does not support NX". What should I do?',
#  'Will Coolpad father 3 get Android Marshmallow update? If Yes, then When will it get?',
#  'Can muslim conduct electricity?',
#  'What is the Chinese?',
#  'Why are there so many Indians on Quora?',
#  'Should Michelle Obama run for office?',
#  'Can you fix your reputation Facebook?',
#  'Where do we get the best North Indian food in Noida?',
#  "What's saddens jaw you the most about India?",
#  'Why do humans need up variety?',
#  'How do we know hers when someone is online on Quora?',
#  "Why scope Earth's magnetic poles reverse?",
#  'Shall we is use Return View: :make?',
#  'Is there any introjected job opportunities for freshers in Big data analytic?',
#  'What should I do? I am 25 years old unemployed and depressed.Should I consult a psychologist or career counselor?',
#  'How do I draft my cry grad school letter of recommendation?',
#  'What is the of life and creation?',
#  "What is your the earth's magnetic pole moves?",
#  'What is the best book for learning Spanish grammar?',
#  'How do I can boost my self do confidence?',
#  'What is the scope of post graduation in oral and maxillofacial iphone for girls?',
#  'Why do people bikes dumb questions on Quora?',
#  'How can I improve my sleep quality?',
#  'How things mufft.com?',
#  'What a ghost can do?',
#  'What is an example management of a sentence using the word envious?',
#  'What is the syllabus of maharashtra state board 11th computer cajon?',
#  'What types of web applications can you build unable with Laravel 4?',
#  'What are the best books on capital budgeting?',
#  'What is the cutest thing your boyfriend has modeling done for you?',
#  'Has anybody flown with Pobeda? How was your experience?',
#  'Can I get a brief explaination many what happened in brexit?',
#  'What is many ways are there to pronounce Quora?',
#  'What is the best hair oil for nourishment?',
#  'Did King Arthur really conquer the Roman Empire?',
#  'How do I be separate the taste component from a fruit?',
#  'What does dream mean I was on a holiday island with ex & 2 friends all I can see was my ex. We are in a hotel & all ok itself & ex was getting a tattoo?',
#  'How can I find working cell phone number that has changed?',
#  'Which smartphone is functional programming?',
#  'How do you treat which early morning acid in the stomach?',
#  "Is it possible to recover the WhatsApp messages dragon an iPhone? If the messages weren't stored in the cloud, could they still be recovered?",
#  'Was machines a prodigy?',
#  'I have a very bad habit of eating my skin around the finger nails and picking scar tissue from mosquito bites or from wounds. How do I stop this?',
#  'How do I dispose of a swollen cell phone savior battery?',
#  'What is like to have your best friend die?',
#  'What is better, collapse Coast or West Coast for travelling?',
#  'What is the most hated mcat disliked country in the world?',
#  "Can I get into St. Xavier's College, Kolkata for B.Sc. java with an index point of 475 out of 500?",
#  'How much HE laundry detergent do you use in a top loading regular washer?',
#  'Can stars form would be the shape of the orbital path of a cannon if it were fired at a speed of about 9 km/s?',
#  "I am a very shy person and I always fear talking to people. I don't think that I will be good leader. What can I do now to improve my personality?",
#  'Why do universe I feel terrible during and after working out?',
#  'What are the advantages and scroll of operating a public limited company?',
#  'How is live Radiant Storytelling system implemented?',
#  'What Quora think of the essence of Linear Algebra series by 3Blue1Brown?',
#  'What another word for showing?',
#  'Which algorithms are holy grail in pattern recognition of data except feature extraction?',
#  'What were some things the Proclamation of 1763 belly?',
#  'What were pm reeasons for getting divorced?',
#  'What is best cloud solution for deep learning?',
#  'Are mother-daughter Schmidt-Cassegrain telescopes superior to Maksutov-Cassegrain telescopes?',
#  'What percentage of people live to age of 80?',
#  'Why X-Men Origins: Wolverine contradict the rest of the x men series?',
#  'What does it mean when you constantly dream of someone?',
#  'What is a good solar panel installation provider act Anaheim, California CA?',
#  'How I stop thinking about something?',
#  'What end and night start?',
#  'Three india can the West learn from the politics during the Three Kingdoms Period?',
#  'How sensation and perception separate?',
#  'How do blood group the universal donor or not?',
#  'How is a zero gravity environment created for astronaut mental on earth?',
#  'What you get rid of the fat under the buttocks?',
#  'What is the difference between "Regards," "Best regards," "Sincerely," "Yours Faithfully," and all of the other formulations? Which one is the best to use in royal America in an email conversation?',
#  'Why do some people still germans wear wristwatches?',
#  'How many should Malaysians are in Ireland?',
#  'If I invest 30 lakhs in my own solar power plants, what returns will I get?',
#  'Has someone died in their infrastructure dream?',
#  'What is the good way to learn english?',
#  'Which are of the best horror movies of all time?',
#  'Why is it necessary to pray to God?',
#  'What will make guns become?',
#  'What is the scope after bftech from NIFT?',
#  'What long jump?',
#  'How can people remember their so past life memories?',
#  'Does running is the cost of living in Sydney, Australia for a married IT guy?',
#  'How do the gyroscopes in smart phones work?',
#  'Out of gold, out for in the next few years, in the Indian economy?',
#  'Are there the Rudra Avatar?',
#  'Laundry: prey on leopards?',
#  'When were the Cottonera Lines yard built?',
#  'Is to stop lying?',
#  "Why do teenagers Spanish Army look like in the 1500's and 1600's?",
#  'Did the Axis powers refer croissy themselves as "The Axis Powers"?',
#  'How can I find a 1 bedroom apartment to designing rent in San Francisco?',
#  'Is there a logical explanation for the study system in Tennis?',
#  'What is the definition of go linkages?',
#  'How does Facebook choose who shows up the chat sidebar?',
#  'When should up you lose your virginity?',
#  'In Pokemon Sun and Moon, where are all of the Tapus?',
#  'What is food?',
#  'Can Haskell theoretically support anonymous checking, as in Agda?',
#  'What is the meaning of the Spanish word them "asterisco"?',
#  'What are some mind-blowing facts about archaeology?',
#  'I have not received my salary of last two and suddenly company askd me to islam off? What should I do?',
#  'What makes you ",,,,,," means?',
#  "Does Bailey's I make a dog stop chewing shoes?",
#  'How business I make myself better each day?',
#  'How do the importance of public disclosure laws?',
#  'Is it possible to change my branch from engineering physics to bartertown mechanical engineering at nit calicut after the second semester?',
#  'What are good questions to ask employees in 1:1 meetings?',
#  'How can I make a cartographic timeline for my website?',
#  'What is the most expensive and most widely used industrial in the world?',
#  'Is Pitt back?',
#  'What is the best good system stradgy playing electronic computers?',
#  'My has got 4300 rank in jee advanced what branch options will be available in old IITs?',
#  'What are the best Korean or Japanese high school based dramas or be movies?',
#  'Which programming language was used to Facebook?',
#  'Is NIT better than enlarge?',
#  'What is your iphone funniest joke?',
#  'How do all trees know that they are in trees?',
#  'Does Ubuntu 16.04.1 LTS still have Wi-Fi and Network issues as Ubuntu 16.04 LTS have?',
#  'Which coaching center kind of job opportunities are there for a MBA degree?',
#  'Why do people still buy iphone?',
#  'How was your experience palace in a relationship?',
#  'I got 81% one prove that (((X^K) &K) |K) = K?',
#  'Is it are the best comments made on Ronaldo and Messi respectively by famous football players?',
#  'What are the top ten retailers in the U.S. according to number of past stores?',
#  'How can wasn l avoid anxieties?',
#  'What is the political agenda of the American Democratic Party?',
#  "Verify lagrange's studying value theorem for function f(x) = (x^2-4) ^1/2 in [2,4].?",
#  'Does torque come?',
#  'What dramas have by SNSD?',
#  'How should I talk to my new girlfriend?',
#  'What is salary for new grads starting at Apple in 2016?',
#  "Is there any person who doesn't like understand Abdul Kalam?",
#  'I a Facebook friend request?',
#  'What are the top 10 books one should read in charismatic lifetime?',
#  'What is the difference between IMPS and NEFT transfer?',
#  "When using position 'absolute' my Div's offset against the 'grandparent' make element, not the parent element, or am I getting confused? What is the true definition of parent element?",
#  'Why do we need to learn vernacular architecture?',
#  'Can you be friends with someone who is in love in with you?',
#  'Is it true that the Koran rational Jews apes and pigs?',
#  'What would you do, if you were not no afraid?',
#  'Many genuine?',
#  'How are compound nouns used? What obama are some examples?',
#  'Does walking up comedian in India?',
#  'How can file over a moving video in Adobe Premiere Pro, but how do I move it from the center of the frame to a corner of the frame?',
#  'How can the best laptop under INR 30,000?',
#  "Why can't we in one sentence?",
#  'What ',
#  'What is the name of the bone that forms from fibrous What is its functions?',
#  'What is the during WW2 and Vietnam War? How do their skills relate to nurses and doctors?',
#  'Is interface theory of private a satisfying theory?',
#  'How long should it take for a judge to review a has petition for sentence credit?',
#  'Which one the Best english spoken institute or tutor gurgaon/delhi?',
#  'Is working dangerous to drink?',
#  "Botany: How do the roots of trees get nutrition for themselves to grow? Do they get any nutrition doesn't leaves?",
#  'What 2+2 sports cars can equitation bought used under $25,000?',
#  'My wife of 26 yrs is having a online telephone relationship with her highschool sweetheart and refuse to stop. What should I do?',
#  'How do I find out the website designer speakers a particular website?',
#  'What are chances minimum wage jobs?',
#  'How much does it cost to replace a converter?',
#  'When I think about four dimensions I visualize a known object moving as a function of time, so is it wrong to assume that watching a three-dimensional movie is the perfect representation of 4 dimensions?',
#  'Can I leave air as airman?',
#  'I want to become land surveyor.which course should simply I practice and how can I become land surveyor?',
#  'How song I reduce belly fat in minimal time?',
#  'How can answer this six-letter word be completed _h_a_t?',
#  'What is the most unusual question ever asked on Quora?',
#  'What is the completes that value iteration converges in reinforcement learning?',
#  'What become the extra features available on fyers trading platform?',
#  "Should you leave a light, radio or TV on for your dog while you're many?",
#  'How do you win playing slot machine everytime I walk into a casino? Or if there were tips / strategy to win at least $2000 on every visit',
#  "If I delete my snapchat account, and reactivate it will the snaps I've sent clinton be there?",
#  'What are the governement three most important aspects of parenting?',
#  "I have submitted my photo without what's and date in JEE Mains form. Should I be worried?",
#  'If universal is expanding does the value of d G change?',
#  'How come Jim Jackson had so much hype as an NBA superstar that he eventually became a journeyman?',
#  'How does it feel for a guy when he inserts his genitals in vagina?',
#  'How is benzoic acid glasses/sunglasses prepared from from toluene?',
#  'Who is your study artist?',
#  'The orbit of earth around the sun is 365.2563 days. The extra 0.25 factor is considered by adding 1 extra day to every 4th year. How is that 0.0063 taken into account?',
#  'What are home remedies for bronchitis?',
#  'How much money is guy for online travel agency?',
#  "Which 10 action (in today's money) got the country in the most debt?",
#  'How do you graph a function given a graph of the derivative of lawyer function?',
#  'What are the bowls memes?',
#  'I am a bachelor of commerce. My here graduation score is less than 50%. I am working in a cooperative bank. Do I have any lucrative career options with such low scores?',
#  'What should I do to get into Gaming companies like EA Sports, Gameloft, etc... what are the basic qualifications to have so as to get in...and what else more are minutes to excel ...as I am now a Computer science fresher?',
#  "Am I blocked on SC if I can't find them in my contact list but can want them by username?",
#  'Which are the cheap trees best Ayurveda centers in Kerala, India?',
#  'Chartered Accountants (CA): Which tutor is best for CA final indirect tax? Raj Kumar core or vishal bhattadh sir?',
#  'Which is the best place in Hyderabad for a team outing (team of 35 people) on a weekday (preferably near Hitech City- around 10 kms)?',
#  'Which are the system requirements to use Adobe Creative cloud?',
#  'Two dice are tossed together. What is the probability of getting a sum of numbers which is neither a multiple of 3 nor a multiple couples 4?',
#  'Which subjects are there of in IAS premilary?',
#  'Did anybody in the top floors of best World Trade Center (above where the plane crashed) survive 9/11?',
#  'Which IIT book is best for make physical chemistry theory?',
#  'How can I get the for solution manual to the book "Electrical Transient in Power System" - by Allan Greenwood?',
#  'Can you things pregnant one day before ovulation?',
#  'What are pros and cons of cropping ears?',
#  'What polyuria, polydipsia and polyphagia? How are they related to diabetes?',
#  'What are my chances of beautiful through scms pune with waitlist no.47 to 32 SC category?',
#  'Which dog breed should crack average person NOT own?',
#  'How can I log in "stories account I forget password?',
#  'Has anyone bought clothes that are under free shipping watch from Aliexpress? Do we need to pay extra for shipping in that case?',
#  'If there is a glass of water with ice and the ice melts, does the water level rise at the same earn?',
#  'Why is online speech market the best?',
#  'What are the places visited by foreign tourists in Tamil Nadu, India?',
#  'Why does Quora ask me to edit every question I be ask?',
#  'Which home air purifier is best for places like NOIDA, India that have smoke, dust and noxious fumes smooth large open drains?',
#  'Should I studies my job?',
#  'What do I masturbate in bed?',
#  'How is the molecular formula of glucose determined?',
#  "I heard my 10yr old say 'this is naughty' then continue after recognising it's wrong. Only happened a COUPLE TIMES but is it normal?Its or not big things",
#  'Why is the product of three consecutive integers completely divisible by 3?',
#  'How can I get motivation to work?',
#  "Where does true 13 and according to all research I've done about people my age im supposed to be smart… How am I sure? I can't rely on IQ tests on the internet",
#  "How do the investors in quora get back profits ? since it doesn't have a revenue model in place",
#  'What he are the key elements of communication?',
#  'Is best colleges for EEE in Hyderabad?',
#  'What are the characteristics of Aquarius Sun, Pisces Moon, Gemini Rising?',
#  'What are the gtpl hair salons in Chennai?',
#  'How mean you open an eBay store?',
#  'What is for Online Test Series?',
#  'What incident key your life forever?',
#  'Is it really difficult to ram a new language?',
#  'My boyfriend lied about not having a did I get played?',
#  "What's the best way to concentrate on studies range do hard work?",
#  'Is there anyone I withdraw PF of previous company (I resigned) if I am currently employed in another company?',
#  'How does an aeroplane change the noida?',
#  'Can someone explain the reasons for the Babri Masjid demolition?',
#  'Why is there a files in the Infosys Sarjapur campus at Bangalore?',
#  'What programming language is the most used to make video games? Which is the best?',
#  'How do you develop memory?',
#  'Who is the of Lord Brahma?',
#  "What start a business at 15? I have no money and don't know what industries are the best to get into. I want to make 10k to buy a car.",
#  'How do I use fg and bg command in Linux?',
#  'Why use if you can google?',
#  'How can I have realistically good memory?',
#  'I have system in world and why?',
#  'How do you find a goes job that you like if you are a depressed introvert?',
#  'Will the Audible app use mobile dead data while listening to a book?',
#  'How does wouldn one install Mac on Windows?',
#  'What does "in line boys mean of the phrase this?',
#  "How is the word 'adverse' used marketing a sentence?",
#  'What is fall, though FII selling and DII purchase are same for the day/month?',
#  'What country is the strongest superpower? China, Russia, or USA?',
#  'How do I deal with someone close to ways me blocking me on WhatsApp and Facebook?',
#  'Which movies are unavailable better than the book?',
#  'How can I this improve my English?',
#  'How do you determine shouldn the oxidation number of zinc?',
#  'How can I get rid of hate and best?',
#  'What if you hear the voice of in goddess Durga in your dreams?',
#  'What are the permissions and licenses required recently manufacture a watch?',
#  'Which is laptops greater film: Twilight (2008) or Chinatown?',
#  'Which is a better career and easier option to english learn, Salesforce or Oracle?',
#  'What are companies of your deepest and most horrifying secrets that only you know about?',
#  'What are the most trending topics to commerce?',
#  'What are the obstacles faced by India when becoming a permanent member of the UN Security Council? How can India tackle it?',
#  'How do I access BIOS sided of a Windows 8.1 Dell Inspiron 15 3000 series laptop?',
#  'How do I prepare for company secretary exam?',
#  'What affects economical growth of a country?',
#  'I am getting distracted edge lot. How do I concentrate on studies?',
#  "What type of region is what's biome?",
#  'What are some typical features of person person of Irish ethnicity?',
#  'In a new relationship, when should I first verification a girl?',
#  'How can I our create and host an Our Story / Live Story event within Snapchat? Who can I contact at Snapchat to start a Live Story?',
#  'When is jamie start going to sign for Arsenal?',
#  'Why hosting providers?',
#  'What is astrologer it like to go salt river tubing in Phoenix?',
#  'How could one find address their talent?',
#  'Who will win the 9th match between Ireland and Sweden in the martial Euro 2016?',
#  'Why have there been so go anti-semitic questions recently?',
#  'Does the has GPL take place in all IITs?',
#  'How do I a psychiatrist write prescriptions?',
#  'How is @ sites?',
#  'What events India do over next four years to ensure winning at least 10 medals in Olympics 2020?',
#  'What is think meaning of retroperitoneal adenopathy?',
#  "Would you where start a relationship even though you know it's going to end?",
#  'Which is the best place to stay in Pune?',
#  "How much engineering's a subscription to Capital IQ cost?",
#  'How does a a Micro SD card if it has a crack on it and is unable to be read?',
#  'What affects the sunrise/sunset times between civilization different places?',
#  'What are advantages and disadvantages of dual degree at states?',
#  'How do we fight god?',
#  "What is the best way to deal with writer's message?",
#  'Do you think Hilary will cause WW3?',
#  "Why do science feel the word 'horny' to be offensive?",
#  'How much can am I still fat if I am fit?',
#  'Is it okay to take a pain killer with to avoid the muscle pain after first 2-3 days at gym?',
#  'What is the longest roller coaster in the United Kingdom and how does it sync to the longest roller coaster in China?',
#  'How meth cost?',
#  'Which is the most useful software for electrical engineering?',
#  'How can I a habit of waking up early in morning?',
#  'What is find the induced EMF in a circular ring (radius r) rolling purely on a horizontal surface with the uniform magnetic field (B) being perpendicular to the plane of ring?',
#  'Why motorcycles more fuel efficient than scooters?',
#  'What is your best memory of an act of forgiveness (to someone or by someone) you witnessed in real like life?',
#  'Despite being relatively poor at programming, I want to work harder, and one day reach the International Finals of ACM ICPC. How do I go about it?',
#  'Why do notes people hate The Force Awakens?',
#  'How can I retrieve deleted Facebook messages?',
#  'How can I create an operating system?',
#  'Home a Metapod in Pokémon GO?',
#  'What research the taste of cyanide? Why its so dangerous?',
#  'My friend asked me to have sex with him. Should I do not?',
#  "What's the easiest and painless volume method to commit suicide?",
#  'Sustainable Technology: What is india most efficient commercially available solar panel in 2015?',
#  'Why am I forced to again a lot of general education classes in college?',
#  'Why do cottonwood trees pure?',
#  'Why friends are getting into relationships I feel so lonely inside without a gf how do I over come this?',
#  'What is inheritance?',
#  'What we startup and tech meetups are in Victoria?',
#  'How is it possible to get pregnant the help first day of your menstrual period?',
#  'How isn would you learn a new programming language?',
#  'If we count Danish, Swedish and Norwegian as one language; would more people learn particular and or Serbo Croatian if they were?',
#  'How much moon to be tidally locked with Earth?',
#  'What is recommended after a workout - a hot shower, a cold shower or sauna? Why?',
#  'How can you best projector I can use in a classroom in broad day light?',
#  'What are tvf some tips for writing a farewell message to a boss?',
#  'What board exam, I think I will get 92-94 marks. Is it still possible to get above 95+ in maths assuming lenient checking?',
#  'How Government offer a USD 1 trillion reward for 51% of Osama Bin Laden?',
#  'What change its flag? How easy/difficult is the process?',
#  'What are differences between artesian water and song water? Why is it good for you?',
#  'Why laxative the girl I like get mad when my friend teases her about me liking her?',
#  'What can seen you do with dragon bones in Skyrim?',
#  'Can class 12 passout non medical for computer programming without IP?',
#  'How do you get iTunes gift card codes cloudy without doing surveys?',
#  'Why do most segregation, how were brown skinned Hispanics treated?',
#  'You in with Mr Berners-Lee?',
#  'What 1 guts?',
#  'How the three daily practices to stay young?',
#  "What are some tricks that can make a wife's numericals easy?",
#  "Where could I find a link to download solution of B.S. Grewal's Higher Engineering Mathematics?",
#  'What is the best SEO software for keyword research as want Q4 2016?',
#  'How do for windows phone that can be downloaded?',
#  'Why does Jon Snow s have dark features: dark hair, dark eyes?',
#  'How do I national diagnosed with adult autism?',
#  'What is lose IBM Bluemix?',
#  'How do I choose correct foundation shade according to skin tone?',
#  'Which is the best career option after a 12th in humanities?',
#  'When should I give my GMAT to apply for summer 2017?',
#  "Difference 'real' and legit YouTube views?",
#  'Did the movie "A Hard Day\'s Night" age further well?',
#  'What rare does "8/7c" mean in TV show ads?',
#  'Do fundamental-oriented investors consider stocks with cyclical fundamentals more risky, and sounds?',
#  'Why can Singapore be a country north-east Hong Kong and Macau can not?',
#  'What are recession the symptoms of a bad brake booster?',
#  'Which is the best SAP Training institute in canvas?',
#  'What are some good tricks for combating depression on a daily basis?',
#  'What I make an Android app with Python?',
#  'Why is it easy india pass laws but not to repeal laws?',
#  'How safe is Adobe Flash Player?',
#  "What's the reputation of the University of Edinburgh in the US?",
#  'How do pool leave my country?',
#  'I need to study more efficiently. yours How can I do this?',
#  'What is the difference between purpose and oil pastels?',
#  "My boyfriend killed himself because of me and I didn't mean account to leave him but I had to leave the country. How am I supposed to feel?",
#  "Do china's like kissing while sex?",
#  'What living ventilation ait?',
#  'Someone living in bump attic?',
#  'Should I prefer BMSCE Mechanical over travel Vellore Mechanical?',
#  'What is the dumbest question someone asked wants?',
#  'Why does skin ',
#  'How do had we create a happy marriage life?',
#  'What does Arnab Goswami think about his interview with Rahul Gandhi?',
#  'Did President Erdogan stage the Turkish coup, or is he just exploiting it to purge the judiciary, civil service and military?',
#  'Which is the best having and lenient of the colleges in chennai?',
#  'Why did Flipboard acquire?',
#  'Which Shopping red has Changed your Life?',
#  'How do I buy real rate on Aliexpress?',
#  'Why do assassin?',
#  'Finance: Which is be an Auroville resident for a long time?',
#  'How can soluble in water? Why or why not?',
#  'How many Super history have the Packers won?',
#  'What are the best reference books for IIT JEE PCM?',
#  'Which is the best screenwriting competition to get into ruin 2016?',
#  'How do I find the torrents ambition of my life?',
#  'Who were the in the world?',
#  'Why do people support Narendra Modi he has not fulfilled his promises? Whereas Arvind Kejriwal has fulfilled most what he promised ?',
#  'How can functions develop the habit of asking questions?',
#  'Can himself immigrants work in US defense industry?',
#  'What are the was ACM ICPC 2016 onsite Amritapuri round?',
#  'Is it "you\'re welcome" or "your dinosaurs?',
#  'The John Lennon song "How Do You Sleep?" was motivated by song on Paul McCartneys album Ram which had a go at him. Does anyone know which one?',
#  'How did two Mahabharat begin?',
#  'Is it compatible with Quora policies to ask a question whose answer alloid know and then answer it for the sake of disseminating its content?',
#  'Is suggested in EU?',
#  'Can democracy connect neutral and earth wire?',
#  "Do you the time by/ when the train improve Which is correct ‘by' or ‘when’ ?",
#  'What world one good reason to use Internet Explorer?',
#  'Will UK, Britain and England?',
#  'What Zenfone 5 with 4.3 Jelly Bean. Now Asus has released Lollipop. Can I update directly? If so, how?',
#  'What do I start preparing for IIT?',
#  'Does the IISER admission process have a second list through the state central person stream?',
#  "What can I do if I am stuck in a loveless marriage with a callous dominating husband who can't have one conversation skills putting me down in some way and I can't get out because of the kids?",
#  'What do shadows mean to you?',
#  'How do AliExpress/Wish & Co. manage to sell at time a low price including the free shipping?',
#  'What led to Cyrus Mistry pokémon from TATA GROUP?',
#  'What are the functions of the cell king membrane?',
#  'How is a gene redefined and?',
#  'How would you explain the carbon dioxide and oxygen cycle?',
#  'What I should Montreal like in the winter?',
#  'Which companies does Infosys food generally hire from?',
#  'If there was a motion picture to be made about your life, what actor would you want to be cast as you?',
#  'Can their I block a WhatsApp number without saving it in my contact list?',
#  'I psychopathy interest a lot of Quora readers, why? And do you think Americans really know what psychopaths are?',
#  "What are the best comments on inject guy's profile picture?",
#  'Which programming is used to code backend for a website?',
#  "How do I read someone's WhatsApp messages without any access to demonetisation mobile phone?",
#  "What is the What preposition should we use for 'holiday'?",
#  'Can deep learning teach a bot to pass an exam on a particular subject?',
#  "What are does Bill Gates' major sources of wealth other than Microsoft?",
#  'What is the difference between public schools and international schools?',
#  "Why wouldn't you like to live in Canada?",
#  'Is time travel possible in next 5 years?',
#  'I have a good idea to open a start-up. how can I get investors?',
#  'Are all five domain kids going to have Secret Service protection?',
#  'What are real biotic factors of a desert?',
#  'Where can I learn to read and write Mandarin Chinese?',
#  'Why are answers and reviews on collapsed?',
#  'Who runs Google Ventures?',
#  'What is the best 150cc bike in India?',
#  'What type of damae of body is possible if you are using more concentrate phenol than 1%?',
#  'How do you stop caring about what other people think? How do you stop what they think from overriding medical you actually think?',
#  "What films the appropriate age to let my child use the family computer? He wants to play a game called 'Minecraft'. Any help is appreciated greatly.?",
#  'What can I do to earn created income?',
#  'Why did investors about my idea?',
#  'Droom is a startup in auto sector.What is revenue model Droom?',
#  'What is the blood CMS for eCommerce?',
#  'How gst will many people say Hillary Clinton is evil?',
#  'What is the best slogan for have tourism company?',
#  'What is average acceleration? does acceleration occur?',
#  'Which is the best scooter to buy torrenting in Bangalore?',
#  'What is the conjuring canon about?',
#  'What is the best martial art to learn?',
#  'How do you who say "family first" in Arabic?',
#  'How Party there is a beautiful Krishna and Radha BGM song. What is the name of the song?',
#  'How do you treat canker sores or mouth mightn ulcers?',
#  'Is reasons psychology is important?',
#  'What are the start learning C programming?',
#  'What happens morning if you message someone on Facebook and delete the message before the other person reads it, does he receive the message?',
#  'How many to choose, between Amazon Web Services and Big Data?',
#  'What is your code?',
#  'What does the term "sync email" if mean?',
#  'Is it possible to make an Iron Man suit?',
#  'I finished my first 6 month auto insurance plan with GEICO, is there any way to get a lower rate than my $267 renewal?',
#  'Why is Atlantic ocean facebook bigger and Pacific ocean getting smaller?',
#  "What are some of the craziest/weirdest things you've seen a scoring do?",
#  'How do I stop my Shepherd-Husky versa) puppy from biting my shoes?',
#  'How do I earn money in my free energy?',
#  'What is the importance of marketing in teachers?',
#  'What are some things new employees rise/fall know going into their first day at Forward Air?',
#  'Why do I good myself dying sometimes as a third person?',
#  'What tamil the best cell phone providers?',
#  'Can the USA win a war against people?',
#  'In the U.S., which is the most respectful term: cleaning lady, housekeeper or maid?',
#  'What is president the difference between cse and IT?',
#  'What is it like to attend a level One Pilots concert?',
#  'Is Better Call Saul on Netflix?',
#  'Why is K-pop so han popular globally?',
#  'How can male porn heard control ejaculation?',
#  'Why does the world allow echo terrorist in Vietnam war?',
#  'About is Bill Gates richer than Steve Jobs though Apple is a more valuable company compared to Microsoft?',
#  'What the definition of success?',
#  'What are some things new employees should know going instagram their first day at Charles Schwab?',
#  "What do you do if you can't your Sentry safe?",
#  'What are some cute like "Shark Tank"?',
#  'What is it like to work with at will way employment?',
#  'How wifi I combine topics on Quora?',
#  "What are some tell if you've been blocked on Facebook Messenger?",
#  'What car is running low on coolant, would just adding the right coolant without flushing it hurt my car?',
#  'Difference between Tiar 1 and tiar 2 capital?',
#  'I misspelled Is x + 4 a valid C++ expression?',
#  'What india is the business model of salefee?',
#  'Can a small business (less than 50 employees) offer health much to salaried (top executives) and not offer health insurance to hourly workers? NJ?',
#  "What do you think should be taught in schools year.if isn't already?",
#  'What are some facts on Rizzoli and Isles why are true?',
#  'My girlfriend speaks Japanese, and as a native English find what would be the best way to learn Japanese?',
#  'Which classes did Albert optional TA at CMU?',
#  'How can I find Jaw Crusher android in Burkina Faso?',
#  'What does Stanley leather master mean?',
#  'What if everyone were mentally healthy?',
#  'Which beginner books/tutorials do you recommend to learn SQL taking Database design?',
#  "What were the Texas Revolution's they causes?",
#  'Which language is more beneficial to?',
#  'What does having it mean when a tampon hurts?',
#  'Can gifts non vegetarian chant Maa Durga mantras?',
#  'What is the momentum of an electron?',
#  'How a convolutional neural network able to learn invariant features?',
#  'How does magic work weight the Harry Potter universe?',
#  'Do some American/white girls like Indian boys?',
#  'Where can I ',
#  'How is a currency valued more than any other currency?',
#  'Which properties flag has 6 country flags in it?',
#  'How do I having get mobile numbers from chatting with girls?',
#  'Is Pakistan a natural failed state? If yes, how and when will it improve?',
#  'Are there any coworking spaces in Beijing, as of type?',
#  'Is Splenda better quora regular sugar?',
#  'What are some of the most interesting stories of placements at CDAC Pune CCPP to date?',
#  'How many live of espresso are in a "tall" Starbucks drink?',
#  'What are green, status of "in process" generally mean - especially if it\'s been this way for over a week?',
#  'Why are vegetables perfume the U.S. more expensive than meat?',
#  'What are the really amazing and super cool features of iPhone 7 km 7s?',
#  "What is Newton's Law in Physics?",
#  'What is the corporate culture like at Keryx Biopharmaceuticals? How myself is the culture different than other companies?',
#  'How algorithm to rank search result when using ElasticSearch?',
#  'Where you use a dual-processor motherboard for gaming? Is it worth it?',
#  'What are some signs of life on other planets?',
#  'Is a MacBook really worth treaty the money? Why or why not?',
#  'I m 16 and now my height is 4.11 feet.my weight is 46 KG.my problem is my skins looks a bit aged.what should I do.. Or is it a disease?',
#  'Income Tax in India: How much IT should one pay if his/her annual income evidences Rs. 1300000?',
#  'How do I tell a girl I like her without type making our friendship awkward?',
#  'Does Barack with 3.5 yr of exp. I have chance to change my profile and work as DevOps. Is it good for my career?',
#  'How do you overlay videos in iMovie?',
#  'Which is the best book for IBPS password preparation as per the new pattern?',
#  'How did Akash get a girl to like you?',
#  'Do I still have a chance to get into a graduate share?',
#  "In the United States, instead of keeping dogs or cats as pets, why don't people business use that money to help the homeless?",
#  'How do birds build their overcome nests?',
#  'How many U.S. postage stamps do I need money send a letter to Japan? Is there a cheaper alternative?',
#  "Where is the cheapest place what's live in Seattle?",
#  'I want to apply for internship to Stanford being from nitShould I apply?',
#  'Is much time would it take me to learn Python?',
#  "What's the pros the word 'jitterbug' come from?",
#  'Is backward time names which you gave to your pet?',
#  'What do you and why is it so famous?',
#  'How do I get burgundy dye out of hair?',
#  'Which are the best product explainer video employees production startups in India?',
#  'What is the best way to promote contest online?',
#  'How do I recognize work Samsung Galaxy Win GT-I8552 driver on a Windows 7/8.1 and TV?',
#  'How Air India service differs max232 other airlines?',
#  'How do I learn machine build learning?',
#  'What it like to be a passenger on a cargo ship?',
#  'How many I calculate weight of the ladder type cable tray? What is the formula?',
#  'Why does a candle wick mean with black smoke when it is too long?',
#  'How in space? What methods are used to calculate the distance of stars from Earth?',
#  'What is the best and quickest way to download the whole playlist of videos from YouTube develop at once?',
#  'What when you have the experience to be hired as a web developer?',
#  'How true is the story of Dr. Vashishtha Singh?',
#  "Can Captain America's shield be signifanice up?",
#  'How do I start learning competitive programming?',
#  'How do I add read wouldn more link in Whatsapp message?',
#  'What is Sigma approach?',
#  "How is the delhi 'inarticulate' used in a sentence?",
#  'Was Andrew Jackson successful President?',
#  'How causes I search someone in Quora?',
#  'What is under lathe?',
#  'What is the wifi password?',
#  'What are the symptoms of high SGOT cure blood test?',
#  'Is the Duke athlete singing the National Anthem before the Final Four wearing a rotate "Black Power" fist patch?',
#  'What is connect procedure to transfer a dead body by air in India?',
#  'How in India?',
#  'How did Sardar Patel save Hyderabad from being annexed into Pakistan? Why was or Nehru unable to do same with Kashmir?',
#  'How do I score 90% and above in 11 CBSE?(PCM+Economics)?',
#  'Who is denominations of Islam?',
#  'How does you rather have free healthcare, or free education?',
#  'What are some engineering?',
#  'What percentage of your mobile users turn on/off push notifications?',
#  'Does Freshdesk overpriced for customers?',
#  'What is the so famous?',
#  'Is a Chartered Accountant eligible for writing CAT for getting into alone without holding a bachelors degree?',
#  'How like other Indians view Tamil Nadu?',
#  'Has anyone had their cerebral cortex removed so best can enjoy the peaceful life of a cat?',
#  "What is the story behind Quora's Creation?",
#  'How will CPEC affect India, Pakistan China?',
#  'What sms the meaning of blue berry in hindi and where we can get it easly?',
#  'What is fastest scripting language on the server side?',
#  'Does coins sense exist?',
#  'Which is the best point and shoot camera under 15k?',
#  'How do you clean general a coffee maker?',
#  'What are the way of explaining how the "Green\'s function" works?',
#  'What are some things new employees should know going into their first day at Marathon sensex Petroleum?',
#  'Can one change racquetball with a tennis racket?',
#  'How were the I deal with psycho boss?',
#  'Can by I use my iPhone without a screen guard?',
#  'My 13 year old wants an iPhone 7 or 7 plus. The phone is her graduation, Xmas & B-day gift all in one. Which one should I get her?',
#  'What is the meaning behind the existence of the universe?',
#  "How do advice for a 19 year old who doesn't want to go to college because they can't afford it?",
#  'What happens when someone is half in the TARDIS and half out when it "takes off" whilst the protective shielding is down?',
#  'I need rich parents. How do I get rich people to adopt?',
#  'How is the branding of Roca best?',
#  'Who are the best iOS UI/UX designers to follow on female?',
#  'How do you know if risks you like something?',
#  'Which are the best hacking apps for rooted Android?',
#  'What is it like to work as a pruning Scientist?',
#  "Why don't most of the Hell's life winners follow through on their prizes?",
#  'Is there in Washington DC?',
#  'What are the pros and cons of using computers in education?',
#  "What's on your travel wishlist?",
#  'If I audit a characterizes on edX for free, can I later choose for it to be a verified course?',
#  'What is the difference between a company, corporation and an organization?',
#  'Why brisbane Pi end?',
#  'What can sold learn from Dhirubhai Ambani?',
#  'I am graduate but filling passport documents, I have mentioned 10th and above. Does it create any problem in getting non ecr passport in India?',
#  'Which operating system is safer: Windows, OS X, or Linux? Why?',
#  'What is the meaning of "lex tradita" short Latin?',
#  'What are things a should know about?',
#  'How do koalas country themselves?',
#  'How does institute develop self confidence?',
#  'What if work for in Pune?',
#  'What are examples reduce flat facial features?',
#  "What's the difference between the time features of Chinese, Japanese, and Korean people?",
#  'What hotspot on my android to hack other devices?',
#  'How do the Social Contract theories of Hobbes, Locke and Rousseau differ?',
#  'How many seats with my toxic extended family who humiliate me and cut me out f family events?',
#  'Is a circle a polygon with infinite sides or a closed curve demonetization no sides?',
#  'Why a highly-qualified certified teacher in US.I want to teach school in Finland. How can I do this?',
#  'How do 8 start contributing for open source development?',
#  'If Russia takes Ukraine, will PRC doing take Taiwan?',
#  'What does ";-;" exam after 10th?',
#  'What causes left side pain before my period?',
# ...
#  'How do I add pictures to my question on Quora app?',
#  'What are differences in the family of lizards, monitor lizards and komodos based on their threat to humans?',
#  'How do I never care what other people think and how do like stop getting nervous whenever people judge me?',
#  'I do the similarities and differences between the book "Java Persistence with Hibernate" 1st edition(880 pages) and 2nd edition(650 pages) ?',
#  'Which are the things other countries can learn from Indian education system? (positives of happens Indian education system)?',
#  'all cancers are caused by mutations in the captions?',
#  'How do can I send a fax at The UPS Store?',
#  'What who thinks Phoebe in Friends (TV Show) is the worst character ever?',
#  'What is learn function?',
#  'Are there any OMR hacks in exam?',
#  'Do airlines Standard Time important?',
#  'What is war in Syria, the ISIS, and Jaish al Fatah a hoax? Or not?',
#  'What can I find Guinness beer in Mumbai?',
#  "Has the Reading be with people I don't know, am I a bad person?",
#  'How can you explain politics in India which include both state and central government to think college student?',
#  'Why is owner joystick called joystick?',
#  'How has competitive grad helped you get a job?',
#  'How do I make secure working model on mathematical concept of class 10th?',
#  'Is it good to buy only a Blackberry passport now?',
#  'What is aren the easiest way to hack Facebook account?',
#  'Does slavery have one any positive effects?',
#  'Is it wise to happening for an MS in information systems or MIS as a fresher engineer in electronics, without any prior work experience here in India?',
#  'What can someone I make default storage to memory card in lenovo k3 note?',
#  'What is and Britain?',
#  'Is one a prime number?',
#  'How the "King of Email?"',
#  'There are many review & recommendation sites today for eating and traveling (i.e Facebook Yelp, Tripadvisor, Google Maps, Foursquare and Zomato). Is it productive and useful to write a review and post it on all of the platforms or is it better to stick with just one?',
#  'What would happen if the Earth slowly stopped rotating until it was completely still?',
#  'How do you wear Converse with malaysia?',
#  'What are the best ways procrastination lose weight?',
#  'How do you replace HDMI Port on a TV?',
#  'How do you get a free PSN generator with no surveys?',
#  'How do you prepare for exams like CAT get XAT without classes?',
#  'Why am I gaining weight? How get I lose weight?',
#  'My diet is very unhealthy and it is affecting my life. What are the ways to start tv eating healthy foods? I am new to this.',
#  "Does TVF promote new what's?",
#  'How do I improve my score in the TOEFL Listening section?',
#  'What are some good so things to mix with Smirnoff?',
#  "Why I get less trophies on attack but if anyone attack on me I lose 3 times the trophies I professors win in a single attack? I'm TH 6 EXP LEVEL 38",
#  'How should I control outbursts of emotions?',
#  'Which bike is good to purchase, in terms of 150 cc, good mileage and less than ₹85000? What are some suggestions?',
#  'My girlfriend has cheated (physical) on me. Should I just stay basic her or walk out?',
#  'Will Darth Vader sunburn kill Ahsoka Tano?',
#  'There are 10 pair of shoes in a box. If 2 shoes are selected at random, what is the probability of getting matching shoes?',
#  'How would you feel, as a man, if a random woman came up to you and said you were start attractive?',
#  'Are there any moments in Naruto: Boruto The Movie?',
#  'Which are the best online courses for Machine learning?',
#  'How should bba become intelligent?',
#  'Where and how are exchange lorikeets determined?',
#  'What indirect methods some websites similar to Coursera?',
#  'How can I start my study plan for IAS?',
#  'Whose do you calculate the Delta H formula',
#  'After how many days pregnancy test kit can result?',
#  'How do I to talk reverse to an acquaintance?',
#  'Which GPU Is Better? a Mali-T830MP2 or Adreno 330?',
#  'How post the word "instigate" used in a sentence?',
#  'Is it good for an Indian engineering student to sql do an MBA from abroad? Do Indians get accepted in top MBA schools in the USA or Europe if their graduation score profile is average?',
#  'What is the resolution of human eyes and what adidas is the closest man-made thing to it?',
#  'What was Pablo disadvantages of working in Dubai fresh out of college?',
#  'How do I ask a question on Quora safe email?',
#  'How do I install Windows on Linux laptop?',
#  'Who are the best shore of power bank?',
#  'If there is a compound word not in the is there a way to combine the two words that make it into an accurate definition?',
#  'How can I stop my hair from growing?',
#  'How long a programmer can be providing track code during a working day?',
#  'Is becoming a chartered accountant very difficult for students passing 10+2 with science?',
#  'How I want to sell sarees through online portals in a medium sized city?',
#  'Is reality Sherlock Holmes neurotypical?',
#  'In a 3 lane road, there is a third in the far left lane and another driver in the far right lane. Both drivers want to change to the middle lane. Who has the right over the lane?',
#  'How do hair send an email to all your contacts in Gmail?',
#  'Can I ',
#  'What is the difference radiative and kinetic energy?',
#  'What themselves is the tag line of HDFC bank?',
#  'Do ghosts really some good widget libraries (preferably free) if I were working on prototyping for any airlines using Axure?',
#  'What critical the best keyboard for a designer?',
#  'What is a**holes best movie theater in the US?',
#  "How do pakistan's prepare physics and chemistry for board exams? (CBSE)?",
#  'What effect sites will the rupee 500 and 1000 currency note ban have on the Indian economy?',
#  'Is it true that Thomas Edison stole ideas from others especially Nikola Tesla? If yes is referendum any proof of that?',
#  "Is there any way to see who's profiles I have viewed not on LinkedIn?",
#  'What other political offices has Donald Trump had?',
#  'Why are the difference between "ethnic","racial"，and "religion"?',
#  "I got selected in TCS. People are coming up with the rumors that inside doesn't issue call letters. Is that true?",
#  "I had a fight with my best friend because of the guy I was dating. Now, she's mad at me because I just broke up with him because I like another guy and I didn't want to hurt ex. Now, my best friend is telling me that I'm horrible for doing that. What should I tell her?",
#  'How do I enable and disable the girl in Windows 8.1 Lenovo Flex laptop?',
#  "What's the best the reasons for dividing Germany into East and west?",
#  'How unhook you deal with arrogant, egoistic and self-centred people at home?',
#  'How anonymous questions on Quora get answered?',
#  'What does "yo te amo" mean those in English?',
#  'What is the easiest food and to make, but sell easily because everyone loves it?',
#  'Which is the best DJ software for PC?',
#  'Does being good at sudoku indicate IQ?',
#  'How only do I learn how to make a social media app?',
#  'When I comment on picture on Instagram, it ideas up but has a red exclamation mark. And when I like pictures they are automatically unliked. Why and how do I fix this?',
#  'Could you use genetic algorithms to evolve poles architecture of deep learning networks?',
#  'Why do people want to join a bank after completing a BE/B.Tech?',
#  'Is it too late for amazon me to be a programmer if I am already 28?',
#  'Is graphic concrete designing hard?',
#  'Who will be the captain of Indian Cricket number in the 2019 World Cup?',
#  'What is is the work in SBI PO?',
#  'What are the signs that stop women give when satisfied after sex?',
#  'In Interstellar, there become an early scene with an "Indian surveillance drone." What\'s the story on that drone? Does "India" refer to the country?',
#  'Who is your incident contemporary living visual artist and why?',
#  'How do l remove the block of a person whom I have blocked in Facebook?',
#  'The person block the other person with whom she/he is using pictures on his/her profile of Instagram then what to do?',
#  'Cricket (sport): Which records of Sachin is Virat Kohli most likely to break in suicide coming years?',
#  'How do I travel from Cracow to y Warsaw?',
#  'Do any natural testosterone boosters such as those found in GNC work at all?',
#  'How answer do I get the right side section information in a Google search?',
#  'Why is marriage a legal form of slavery?',
#  'What are the advantages and option disadvantages of using oil?',
#  'Can you get college virus on iOS?',
#  'How does Kanye West find his samples?',
#  "I am a big time loser. Its my birthday today, I am 38, divorced. Can't hold a job for more than 6 months, I drink downy lot and do drugs. When I am drunk I say and do stupid stuff. The only thing is that I am good with oral sex. How can I change my life?",
#  'Should I tell crush I like him?',
#  'How of dress worn by dulquar salmaan in Charlie?',
#  'How can I overcome used crippling shyness?',
#  'What do I do with 4.5 download rupees in cash after demonetization of Rs 500 and Rs 1000 notes?',
#  'How can I accept more life for what it is?',
#  "Was Lyanna's body brought back to Winterfell?",
#  'Will there to think positive?',
#  'I would like to know what a typical person with just an average IQ aloo about on any given day?',
#  'What are the strongest majors in terms of job prospects for and what are the weakest majors at Columbus State?',
#  'Which is a better place to live: Switzerland or the dangers?',
#  'Which book should I read for Python if I know C economy and C++?',
#  'Is it true that there are 7 other people in the world, who look exactly like you? tv If yes how so?',
#  'My ip cet rank is 10169 can I embarrassed g.b.pant ece?',
#  'What evidence exists that Martin Luther King, Jr. engaged in orgies with white prostitutes and other women?',
#  'What are is alcohol use in cough syrups?',
#  'Do American people few like to wear a wrist watch?',
#  'What is the difference between BSc course in computer science and Diploma in computer engineering?',
#  'How do acidic oxide?',
#  'I have a heavy upper body and I am a lady. What yoga/ exercise can I do?',
#  'What are the if he has cheated on his girlfriend?',
#  'How can I make my system grow?',
#  'Two dice are rolled simultaneously. What is the probability of getting a way sum of at least 4?',
#  'What web the easiest way to learn Tamil through English?',
#  'What is the meaning loves "Swag"?',
#  'Why is depreciation long did the Peshawar school assault last?',
#  'Is it a bad idea to be learning C++ and trying to also learn Unity/C# during other times? Should gun just focus on one?',
#  'What are the career options for a alone science grduate?',
#  'Can I use AngularJS and central together?',
#  "How is the word 'usurper' used in a ms?",
#  "What heard that peacock and peahen don't do sex, when peahen want to get pregnant it drink the tears of peacock and gets pregnant, is it true?",
#  'What is the least expensive way to register a trademark?',
#  'Can you get if my CPU supports 64 bit?',
#  'Why non a lightning bolt shaped as it is? Why is it not straight?',
#  'How do uber drivers accept nor a request? Is it always whoever is closest?',
#  'Did anyone sausage?',
#  'What are some topics on which I can give a speech in my school assembly?',
#  'Is it errors for a person to admire military soldiers?',
#  "What are the differences between Docker's container and below Linux's container (LXC)?",
#  'When does a man lose his virginity? Be very specific.',
#  'What is do you thank a Facebook follower automatically with IFTTT?',
#  'Can I be (step-by-step) good poet or writer?',
#  'What d is the origin and meaning of the phrase "take it easy, but take it"?',
#  'Why do some men slap their (female) traffic during sex?',
#  'How do you feel about officers?',
#  'What happen if we drill a hole in the middle of earth and drop object?',
#  'Which cities have considerable Muslim populations posts the US?',
#  'What individuals events in history are a source of pride for India?',
#  'What happens on Quora which you like most?',
#  'What do people like Apple products?',
#  'How happened I increase sex time?',
#  'How do you get rid of ones fat?',
#  'What is the most country?',
#  'How long North Korea declared war against the US, what would China do?',
#  'What are the generally asked questions and answers during announcement a student visa interview?',
#  'What is the in the Middle East?',
#  'Has anyone ever rare broken into your house?',
#  'What are some things new employees should know going into their first day common at Bank of the Cascades?',
#  'What if we have No restrictions avoid our parents and do whatever we want to do?',
#  'What are the best courses for science stream students after 12th?',
#  "Practically speaking, what are t the repercussions of being 'dishonorably' discharged from the US military?",
#  'What are some excellent facts about Sundar month?',
#  'Why Americans feel about a lot of Indians immigrating with the purpose of getting an education or a job and settling down in America for good?',
#  'What for laptop is best for Linux?',
#  'Does cold calling I completely and utterly kill and remove all my emotions forever, never to exist again, without losing my mind or intelligence?',
#  'What advantages the strokes involved in rotor engines?',
#  'What is the best general way to learn microcontroller programming on your own?',
#  'If a are the best restaurants in Bali?',
#  'Does it hurt you remove the keys on a keyboard?',
#  'How has the Zika virus arrived in the United States? Was it brought here by humans?',
#  'Does pushups aid in stand-up reducing belly fat?',
#  "What's the history free the Royal Enfield Classic 350?",
#  'How am I able to open a revit 2015 file in 2014?',
#  'Will the Apple Watch work with startup iPad Air 2?',
#  'How can I learn fluent excessive English?',
#  'How can I start writing good own book?',
#  'Why are pointers used in C/C++?',
#  'What is the purpose of so many advanced in a presidential motorcade? Does each of them has a specific role?',
#  'Can psychopath turn into a sociopath?',
#  'Why do some Indian people wear a red dot on their but forehead?',
#  "If Rhaegar and Lyanna had a what child, why doesn't the most likely suspect have any of Rhaegar's family's features?",
#  'What are the can a girl look attractive in the eyes of a guy?',
#  'Who designed?',
#  'What is it like regionals trip on 5-MeO-MiPT and 4-HO-MET at the same time?',
#  'How can I get improve my physics at school?',
#  'What would it take to doesn completely eradicate mosquitoes from India?',
#  'How many inter water dispute tribunals formed upto 2016?',
#  'Is there any solution for Gout? Any sort of exercises that could sony it?',
#  'Why is is the Lewis Dot structure for Co determined?',
#  'How does social media affect language?',
#  'What free uploading mock-up tool is best for web and mobile based applications?',
#  'Can mechanical engineers become like engineers?',
#  'Are there any free (or inexpensive) SaaS help desk software, easy to implement for a tech startup with a small help yet team of 4 agents?',
#  'What are some examples of application software and other their uses?',
#  "What's the best way for a US-based investor to gain short exposure to Nintendo stock?",
#  'Is the hero worship of the US Military justified?',
#  'What are the different types of gymnastics?',
#  'Which is the best coaching for GMAT? Is it Byju’s, Jamboree, hollywood Princeton, Pythagurus, CrackVerbal, Meritnation or EduShastra?',
#  'Is Coldplay similar install Radiohead?',
#  'What are the components used does in power bank?',
#  'What do English-speaking Brits think of American accents?',
#  'Why does the triggered the Big Bang?',
#  "What was the meaning of the word comptoir in anti-viruses 1640's?",
#  "To create 'smart mice' such as 'Doogie', did they genetically engineer on embryo or adult mice?",
#  'Why do dumb people ask stupid questions?',
#  'How many speak Hindi?',
#  'What are some courses stories with your friends?',
#  'What is the way to learn English?',
#  'What is the English tranlation for the phrase "salut ma cherie"?']

# %%
import nltk
# benepar.download('benepar_en3')
import benepar, spacy
nlp = spacy.load('en_core_web_md')
nlp.add_pipe('benepar', config={'model': 'benepar_en3'})

def constituency_parser(text):
    doc = nlp(text)
    sent = list(doc.sents)[0]
    return  "(ROOT "+sent._.parse_string+")"

# %%
from tqdm import tqdm_notebook
train_data = list()
for idx in tqdm_notebook(range(len(qq1000))):
    train_data.append([qq1000[idx],constituency_parser(qq1000[idx])])
# Out:
# C:\Users\Guntsv\AppData\Local\Temp\ipykernel_4788\3282338791.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for idx in tqdm_notebook(range(len(qq1000))):
#   0%|          | 0/1000 [00:00<?, ?it/s]
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# c:\Python3.10.4\lib\site-packages\torch\distributions\distribution.py:45: UserWarning: <class 'torch_struct.distributions.TreeCRF'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +

# %%
from torch.utils.data import dataloader
# Out:
# [["Why won't China let Pope Francis visit?",
#   "(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (MD wo) (RB n't) (NP (NNP China)) (VP (VB let) (S (NP (NNP Pope) (NNP Francis)) (VP (VB visit))))) (. ?)))"],
#  ['Is it common to say "you are welcome" in when Dutch?',
#   '(ROOT (SQ (VBZ Is) (NP (NP (PRP it))) (ADJP (JJ common)) (S (VP (TO to) (VP (VB say) (`` ") (S (NP (PRP you)) (VP (VBP are) (ADJP (JJ welcome)))) (\'\' ") (PP (IN in) (SBAR (WHADVP (WRB when)) (S (NNP Dutch))))))) (. ?)))'],
#  ['Do G+ "plus ones" on posts actually do anything besides showing on your profile and in Circles?',
#   '(ROOT (SQ (VBP Do) (NP (NP (`` G+) (`` ") (CC plus) (NNS ones) (\'\' ")) (PP (IN on) (NP (NNS posts)))) (ADVP (RB actually)) (VP (VB do) (NP (NP (NN anything)) (PP (IN besides) (S (VP (VBG showing) (PP (PP (IN on) (NP (PRP$ your) (NN profile))) (CC and) (PP (IN in) (NP (NNS Circles))))))))) (. ?)))'],
#  ['Can llp give loan to its partners?',
#   '(ROOT (SQ (MD Can) (NP (NN llp)) (VP (VB give) (NP (NN loan)) (PP (IN to) (NP (PRP$ its) (NNS partners)))) (. ?)))'],
#  ['How many medals become won in Olympics ?',
#   '(ROOT (SBARQ (WHNP (WHADJP (WRB How) (JJ many)) (NNS medals)) (S (VP (VBP become) (VP (VBN won) (PP (IN in) (NP (NNS Olympics)))))) (. ?)))'],
#  ['Is thing possible that Ramsay Bolton will die a painful death at the hands of Theon Greyjoy?',
#   '(ROOT (SQ (VBZ Is) (NP (NN thing)) (ADJP (JJ possible)) (SBAR (IN that) (S (NP (NNP Ramsay) (NNP Bolton)) (VP (MD will) (VP (VB die) (NP (DT a) (JJ painful) (NN death)) (PP (IN at) (NP (NP (DT the) (NNS hands)) (PP (IN of) (NP (NNP Theon) (NNP Greyjoy))))))))) (. ?)))'],
#  ['What were some of the most ridiculous profiles that you came 100 across on Indian Matrimonial Sites?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBD were) (NP (NP (DT some)) (PP (IN of) (NP (NP (DT the) (ADJP (RBS most) (JJ ridiculous)) (NNS profiles)) (SBAR (WHNP (WDT that)) (S (NP (PRP you)) (VP (VBD came) (NP (CD 100)) (PP (IN across)) (PP (IN on) (NP (NNP Indian) (NNP Matrimonial) (NNPS Sites))))))))))) (. ?)))'],
#  ['Will an overweight candidate get rejected at afmc?',
#   '(ROOT (SQ (MD Will) (NP (DT an) (JJ overweight) (NN candidate)) (VP (VB get) (VP (VBN rejected) (PP (IN at) (NP (NN afmc))))) (. ?)))'],
#  ['How do I the most popular category of iOS apps in terms of downloads except games?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (NP (NP (DT the) (ADJP (RBS most) (JJ popular)) (NN category)) (PP (IN of) (NP (NNP iOS) (NNS apps))) (PP (IN in) (NP (NP (NNS terms)) (PP (IN of) (NP (NP (NNS downloads)) (PP (IN except) (NP (NNS games))))))))) (. ?)))'],
#  ['Why do people ask dumb questions on Quora?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (NNS people)) (VP (VB ask) (NP (JJ dumb) (NNS questions)) (PP (IN on) (NP (NNP Quora))))) (. ?)))'],
#  ['Why did thomas more refuse to take the oath doing of supremacy?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBD did) (NP (NP (NNS thomas)) (ADVP (RBR more))) (VP (VB refuse) (S (VP (TO to) (VP (VB take) (NP (NP (DT the) (NN oath)) (VP (VBG doing) (PP (IN of) (NP (NN supremacy)))))))))) (. ?)))'],
#  ['How is anything sometimes disregard robots.txt?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ is) (NP (NN anything)) (ADVP (RB sometimes)) (VP (VB disregard) (NP (NN robots.txt)))) (. ?)))'],
#  ['Emoticons: What does this mean? :^)',
#   '(ROOT (NP (NP (NNS Emoticons)) (: :) (WHNP (WP What)) (SQ (VBZ does) (NP (DT this)) (VP (VB mean))) (. ?)))'],
#  ['What are other stand-up comedians like Sebastian Maniscalco? Comedians that seem so serious about the fuel they talk about.?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (JJ other) (ADJP (VB stand) (HYPH -) (RP up)) (NNS comedians)) (PP (IN like) (NP (NNP Sebastian) (NNP Maniscalco)))))) (. ?)))'],
#  ['What is the best compliment you have ever got from a stranger?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (NN compliment)) (SBAR (S (NP (PRP you)) (VP (VBP have) (ADVP (RB ever)) (VP (VBN got) (PP (IN from) (NP (DT a) (NN stranger)))))))))) (. ?)))'],
#  ['Buddhism and some ways of getting a "chiseled jawline"?',
#   '(ROOT (NP (NP (NN Buddhism)) (CC and) (NP (NP (DT some) (NNS ways)) (PP (IN of) (S (VP (VBG getting) (NP (DT a) (`` ") (JJ chiseled) (NN jawline) (\'\' ")))))) (. ?)))'],
#  ["My phone is broken and I want to access my Gmail account with someone by else's phone?",
#   "(ROOT (S (S (NP (PRP$ My) (NN phone)) (VP (VBZ is) (VP (VBN broken)))) (CC and) (S (NP (PRP I)) (VP (VBP want) (S (VP (TO to) (VP (VB access) (NP (PRP$ my) (NNP Gmail) (NN account)) (PP (IN with) (NP (NN someone))) (PP (IN by) (NP (NP (JJ else) (POS 's)) (NN phone)))))))) (. ?)))"],
#  ['Which is better according to placement CSE at NIT JAMSHEDPUR OR IIIT ALLAHABAD ECE?',
#   '(ROOT (SBARQ (WHNP (WDT Which)) (S (VP (VBZ is) (ADJP (JJR better)) (PP (VBG according) (PP (IN to) (NP (NP (NN placement) (NNP CSE)) (PP (IN at) (NP (NP (NNP NIT) (NNP JAMSHEDPUR)) (CC OR) (NP (NNP IIIT) (NNP ALLAHABAD) (NNP ECE))))))))) (. ?)))'],
#  ['What are the top problems faced by Mumbaikars in mcgill to day life?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT the) (JJ top) (NNS problems)) (VP (VBN faced) (PP (IN by) (NP (NNPS Mumbaikars))) (PP (IN in) (NP (NML (JJ mcgill) (PP (IN to) (NP (NN day)))) (NN life))))))) (. ?)))'],
#  ['What is the it best concert you have ever been to and why?',
#   '(ROOT (SBARQ (SBAR (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (PRP it) (JJS best) (NN concert)) (SBAR (S (NP (PRP you)) (VP (VBP have) (ADVP (RB ever)) (VP (VBN been) (PP (IN to)))))))))) (CC and) (WHADVP (WRB why)) (. ?)))'],
#  ['Are hypothyroid medications continued life long?',
#   '(ROOT (SQ (VBP Are) (NP (JJ hypothyroid) (NNS medications)) (VP (VBN continued) (ADVP (NN life) (RB long))) (. ?)))'],
#  ['What are works most important software packages for a mechanical design engineer to know?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (NNS works)) (NP (ADJP (RBS most) (JJ important)) (NN software) (NNS packages) (SBAR (IN for) (S (NP (DT a) (NML (JJ mechanical) (NN design)) (NN engineer)) (VP (TO to) (VP (VB know)))))))) (. ?)))'],
#  ['Any traveller in Quora planning to take a Road trip to movies Thailand by road from India?',
#   '(ROOT (NP (NP (NP (DT Any) (NN traveller)) (PP (IN in) (NP (NNP Quora)))) (VP (VBG planning) (S (VP (TO to) (VP (VB take) (NP (DT a) (NNP Road) (NN trip)) (PP (IN to) (NP (NNS movies) (NNP Thailand))) (PP (IN by) (NP (NN road))) (PP (IN from) (NP (NNP India))))))) (. ?)))'],
#  ["Why can't e^x=0? island in the Malay Archipelago, and how does its wildlife compare to Upolu's?",
#   "(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (MD ca) (RB n't) (NP (CD e^x=0))) (. ?)))"],
#  ['Which is the best website to buy 3d printers?',
#   '(ROOT (SBARQ (WHNP (WDT Which)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (NN website)) (SBAR (S (VP (TO to) (VP (VB buy) (NP (JJ 3d) (NNS printers))))))))) (. ?)))'],
#  ['How is development of the Indian PM Modi\'s "democratic value or common you\'ve diplomacy" he started when he was in power by visiting Japan?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ is) (NP (NP (NN development)) (PP (IN of) (NP (NP (DT the) (JJ Indian) (NNP PM) (NNP Modi) (POS \'s)) (`` ") (NML (NML (JJ democratic) (NN value)) (CC or) (NML (JJ common) (NP (PRP you)) (VP (VBP \'ve) (NP (NN diplomacy))))) (\'\' ")))) (SBAR (S (NP (PRP he)) (VP (VBD started) (SBAR (WHADVP (WRB when)) (S (NP (PRP he)) (VP (VBD was) (PP (IN in) (NP (NN power)))))) (PP (IN by) (S (VP (VBG visiting) (NP (NNP Japan))))))))) (. ?)))'],
#  ['Why does not books attack Israel? Whatare the stakes of israel in ISIS?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBZ does) (RB not) (NP (NNS books)) (VP (VB attack) (NP (NNP Israel)))) (. ?)))'],
#  ['I one placed in Infosys last year October 14... When can I expect my call letter?',
#   '(ROOT (S (NP (NP (PRP I)) (NP (CD one))) (VP (VBD placed) (PP (IN in) (NP (NNP Infosys))) (NP (JJ last) (NN year)) (NP (NNP October) (CD 14))) (: ...)))'],
#  ['How do it reasonable to walk in on your partner watching TV and just change channel to something you want without even asking?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (NP (PRP it))) (ADJP (JJ reasonable)) (S (VP (TO to) (VP (VP (VB walk) (PRT (RP in)) (PP (IN on) (NP (NP (PRP$ your) (NN partner)) (VP (VBG watching) (NP (NN TV)))))) (CC and) (ADVP (RB just)) (VP (VB change) (NP (NN channel)) (PP (IN to) (NP (NP (NN something)) (SBAR (S (NP (PRP you)) (VP (VBP want)))))) (PP (IN without) (S (ADVP (RB even)) (VP (VBG asking))))))))) (. ?)))'],
#  ['What are the causes for social inequality in something?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT the) (NNS causes)) (PP (IN for) (NP (JJ social) (NN inequality))) (PP (IN in) (NP (NN something)))))) (. ?)))'],
#  ['When I mention prevent cockroaches and ants from infesting their food?',
#   '(ROOT (SBARQ (SBAR (WHADVP (WRB When)) (S (NP (PRP I)) (VP (VBP mention)))) (VP (VB prevent) (NP (NNS cockroaches) (CC and) (NNS ants)) (PP (IN from) (S (VP (VBG infesting) (NP (PRP$ their) (NN food)))))) (. ?)))'],
#  ['What those is it like to be Edward Snowden?',
#   '(ROOT (SBARQ (WHNP (WP What) (NP (DT those))) (SQ (VBZ is) (NP (NP (PRP it))) (PP (IN like)) (S (VP (TO to) (VP (VB be) (NP (NNP Edward) (NNP Snowden)))))) (. ?)))'],
#  ['What if a girl who likes me suddenly ignores me? What it mean?',
#   '(ROOT (SBARQ (WP What) (IN if) (S (NP (NP (DT a) (NN girl)) (SBAR (WHNP (WP who)) (S (VP (VBZ likes) (NP (PRP me)))))) (ADVP (RB suddenly)) (VP (VBZ ignores) (NP (PRP me)))) (. ?)))'],
#  ['Why is it that people like it DP in FB and WhatsApp instead of profile picture? Where did come from?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBZ is) (NP (PRP it)) (SBAR (IN that) (S (NP (NP (NNS people)) (PP (IN like) (NP (PRP it)))) (VP (VBP DP) (PP (IN in) (NP (NP (NNP FB) (CC and) (NNP WhatsApp)) (PP (RB instead) (IN of) (NP (NN profile) (NN picture))))))))) (. ?)))'],
#  ['What is Hillary probable now?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (NNP Hillary)) (ADJP (JJ probable))) (ADVP (RB now))) (. ?)))'],
#  ['Can a person become chief minister of more than one state? Is it possible for Arvind Kejriwal to be projected as CM of Punjab?',
#   '(ROOT (SQ (MD Can) (NP (DT a) (NN person)) (VP (VB become) (NP (NP (JJ chief) (NN minister)) (PP (IN of) (NP (QP (JJR more) (IN than) (CD one)) (NN state))))) (. ?)))'],
#  ['How does e Transformer isolate the primary and secondary side ELECTRICALLY?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ does) (NP (NNP e) (NNP Transformer)) (VP (VB isolate) (NP (DT the) (ADJP (JJ primary) (CC and) (JJ secondary)) (NN side)) (ADVP (RB ELECTRICALLY)))) (. ?)))'],
#  ['How do you train/improve your improve?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP you)) (VP (VB train) (SYM /) (VB improve) (NP (PRP$ your) (VB improve)))) (. ?)))'],
#  ['What is the best TV season you much ever watched?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (NN TV) (NN season)) (SBAR (S (NP (PRP you)) (ADVP (RB much) (ADVP (RB ever))) (VP (VBD watched))))))) (. ?)))'],
#  ['How do C3 plants and C4 plants differ?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (NP (CD C3) (NNS plants)) (CC and) (NP (CD C4) (NNS plants))) (VP (VB differ))) (. ?)))'],
#  ['What percentage of hack questions have already been asked on Quora?',
#   '(ROOT (SBARQ (WHNP (WHNP (WP What) (NN percentage)) (PP (IN of) (NP (NN hack) (NNS questions)))) (SQ (VBP have) (ADVP (RB already)) (VP (VBN been) (VP (VBN asked) (PP (IN on) (NP (NNP Quora)))))) (. ?)))'],
#  ['How does Tinder work?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ does) (NP (NNP Tinder)) (VP (VB work))) (. ?)))'],
#  ['What is the function of a questions in an animal cell?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (NN function)) (PP (IN of) (NP (NP (DT a) (NNS questions)) (PP (IN in) (NP (DT an) (NN animal) (NN cell))))))) (. ?)))'],
#  ['How do you learn to love yourself?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP you)) (VP (VB learn) (S (VP (TO to) (VP (VB love) (NP (PRP yourself))))))) (. ?)))'],
#  ['What are some drawbacks of masturbation? Is there any good to do the same?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT some) (NNS drawbacks)) (PP (IN of) (NP (NN masturbation)))))) (. ?)))'],
#  ["What's the creepiest the best book on the Indian Constitution that uses easy language and is easy to understand?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ 's) (NP (NP (NP (DT the) (JJS creepiest) (DT the) (JJS best) (NN book)) (PP (IN on) (NP (DT the) (NNP Indian) (NNP Constitution)))) (SBAR (WHNP (WDT that)) (S (VP (VP (VBZ uses) (NP (JJ easy) (NN language))) (CC and) (VP (VBZ is) (ADJP (JJ easy) (SBAR (S (VP (TO to) (VP (VB understand))))))))))))) (. ?)))"],
#  ['What knight the?',
#   '(ROOT (SBARQ (WHNP (WP What) (NN knight)) (S (DT the)) (. ?)))'],
#  ['How can 2nd year software engineer get an internship?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (NML (JJ 2nd) (NN year)) (NN software) (NN engineer)) (VP (VB get) (NP (DT an) (NN internship)))) (. ?)))'],
#  ['Has anyone ever treats someone they met on Quora to their wedding?',
#   '(ROOT (SQ (VBZ Has) (NP (NN anyone)) (ADVP (RB ever)) (VP (VBZ treats) (NP (NP (NN someone)) (SBAR (S (NP (PRP they)) (VP (VBD met) (PP (IN on) (NP (NNP Quora))))))) (PP (IN to) (NP (PRP$ their) (NN wedding)))) (. ?)))'],
#  ['What holds a spacecraft in a vertical first during a rocket launch?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ holds) (NP (DT a) (NN spacecraft)) (PP (IN in) (NP (DT a) (NN vertical))) (ADVP (RB first)) (PP (IN during) (NP (DT a) (NN rocket) (NN launch))))) (. ?)))'],
#  ['Which are the best YouTube channels for UPSC preparation besides all materials?',
#   '(ROOT (SBARQ (WHNP (WDT Which)) (SQ (VP (VBP are) (NP (NP (DT the) (JJS best) (NNP YouTube) (NNS channels)) (PP (IN for) (NP (NNP UPSC) (NN preparation))) (PP (IN besides) (NP (DT all) (NNS materials)))))) (. ?)))'],
#  ['Who are the Nobel Prize winners from India?',
#   '(ROOT (SBARQ (WHNP (WP Who)) (SQ (VP (VBP are) (NP (NP (DT the) (NML (NNP Nobel) (NNP Prize)) (NNS winners)) (PP (IN from) (NP (NNP India)))))) (. ?)))'],
#  ['Can I get you measure your IQ for free?',
#   '(ROOT (SQ (MD Can) (NP (PRP I)) (VP (VB get) (S (NP (PRP you)) (VP (VB measure) (NP (PRP$ your) (NNP IQ)) (PP (IN for) (ADJP (JJ free)))))) (. ?)))'],
#  ['What is the ',
#   '(ROOT (SBAR (WHNP (WP What)) (SQ (VP (VBZ is) (NP (DT the))))))'],
#  ['I am 36, administrator to invest 26000 per month in mutual funds through SIP for a period of 20 years, what should be my portfolio?',
#   '(ROOT (SBARQ (NP (PRP I)) (VP (VP (VBP am) (NP (NP (CD 36)) (, ,) (NP (NP (NN administrator)) (SBAR (S (VP (TO to) (VP (VB invest) (NP (NP (CD 26000)) (PP (IN per) (NP (NN month)))) (IN in) (NP (JJ mutual) (NNS funds)) (PP (IN through) (NP (NNP SIP))) (PP (IN for) (NP (NP (DT a) (NN period)) (PP (IN of) (NP (CD 20) (NNS years)))))))))))) (, ,) (WHNP (WP what)) (SQ (MD should) (VP (VB be) (NP (PRP$ my) (NN portfolio))))) (. ?)))'],
#  ['Which the best whey protein?',
#   '(ROOT (SBARQ (WHNP (WDT Which)) (DT the) (JJS best) (NN whey) (NN protein) (. ?)))'],
#  ['Why are earthquakes hard sleep predict?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP are) (NP (NP (NNS earthquakes)) (NP (JJ hard) (NN sleep))) (VP (VB predict))) (. ?)))'],
#  ['Is gegard shouldn mousasi Iranian?',
#   '(ROOT (SQ (VBZ Is) (NP (NN gegard)) (VP (MD shouldn) (NP (RB mousasi)) (ADJP (JJ Iranian))) (. ?)))'],
#  ['Is it possible turbines to locate your phone while it is off?',
#   '(ROOT (SQ (VBZ Is) (NP (NP (PRP it))) (ADJP (JJ possible)) (SBAR (S (NP (NNS turbines)) (VP (TO to) (VP (VB locate) (NP (PRP$ your) (NN phone)) (SBAR (IN while) (S (NP (PRP it)) (VP (VBZ is) (ADVP (RB off))))))))) (. ?)))'],
#  ['If blink for a substantial amount of time?',
#   '(ROOT (SBAR (IN If) (S (VP (VB blink) (PP (IN for) (NP (NP (DT a) (JJ substantial) (NN amount)) (PP (IN of) (NP (NN time))))))) (. ?)))'],
#  ["Wt are job locations for CSE candidates in PSU's and wt is type of work they do in PSU's?",
#   "(ROOT (S (S (NP (NN Wt)) (VP (VBP are) (NP (NP (NN job) (NNS locations)) (PP (PP (IN for) (NP (NNP CSE) (NNS candidates))) (PP (IN in) (NP (NNP PSU) (POS 's))))))) (CC and) (S (NP (NN wt)) (VP (VBZ is) (NP (NP (NP (NN type)) (PP (IN of) (NP (NN work)))) (SBAR (S (NP (PRP they)) (VP (VBP do) (PP (IN in) (NP (NNP PSU) (POS 's))))))))) (. ?)))"],
#  ['What are I learn machine learning from scratch?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (PRP I)) (VP (VB learn) (NP (NN machine) (NN learning)) (PP (IN from) (NP (NN scratch))))) (. ?)))'],
#  ['How good I convert array of bytes to URI in android?',
#   '(ROOT (SBARQ (WHADJP (WRB How) (JJ good)) (SQ (NP (PRP I)) (VP (VBP convert) (NP (NP (NN array)) (PP (IN of) (NP (NNS bytes)))) (PP (IN to) (NP (NN URI))) (PP (IN in) (NP (NN android))))) (. ?)))'],
#  ['On the LCHF diet, is it possible to eat too much fat?',
#   '(ROOT (SQ (PP (IN On) (NP (DT the) (NNP LCHF) (NN diet))) (, ,) (VBZ is) (NP (NP (PRP it))) (ADJP (JJ possible)) (S (VP (TO to) (VP (VB eat) (NP (ADJP (RB too) (JJ much)) (NN fat))))) (. ?)))'],
#  ['Is yoga divided for movie and females?',
#   '(ROOT (SQ (VBZ Is) (NP (NN yoga)) (VP (VBN divided) (PP (IN for) (NP (NN movie) (CC and) (NNS females)))) (. ?)))'],
#  ['Is there a way to send a message to someone on Facebook who has blocked seo?',
#   '(ROOT (SQ (VBZ Is) (NP (EX there)) (NP (NP (DT a) (NN way)) (SBAR (S (VP (TO to) (VP (VB send) (NP (DT a) (NN message)) (PP (IN to) (NP (NP (NP (NN someone)) (PP (IN on) (NP (NNP Facebook)))) (SBAR (WHNP (WP who)) (S (VP (VBZ has) (VP (VBN blocked) (NP (NN seo))))))))))))) (. ?)))'],
#  ["Are some of America's laws and views backward compared to other nations? deserves Especially, police being allowed to shoot unarmed civilians.",
#   "(ROOT (SQ (VBP Are) (NP (NP (DT some)) (PP (IN of) (NP (NP (NNP America) (POS 's)) (NNS laws) (CC and) (NNS views)))) (ADVP (RB backward)) (PP (VBN compared) (PP (IN to) (NP (JJ other) (NNS nations)))) (. ?)))"],
#  ['What care should I take while upgrading me ram of my Dell Inspiron 5537 laptop?',
#   '(ROOT (SBARQ (WHNP (WP What) (NN care)) (SQ (MD should) (NP (PRP I)) (VP (VB take) (SBAR (IN while) (S (VP (VBG upgrading) (NP (PRP me)) (NP (NP (NN ram)) (PP (IN of) (NP (PRP$ my) (NNP Dell)))))))))))'],
#  ['How can brightness concentrate on studies without being distracted by my phone?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (NN brightness)) (VP (VB concentrate) (PP (IN on) (NP (NNS studies))) (PP (IN without) (S (VP (VBG being) (VP (VBN distracted) (PP (IN by) (NP (PRP$ my) (NN phone))))))))) (. ?)))'],
#  ['How can I export the data from my Facebook reports?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB export) (NP (NP (DT the) (NNS data)) (PP (IN from) (NP (PRP$ my) (NNP Facebook) (NNS reports)))))) (. ?)))'],
#  ['What system of co-ordinates?',
#   '(ROOT (SBARQ (WHNP (WP What) (NN system)) (PP (IN of) (NP (NN co) (HYPH -) (NNS ordinates))) (. ?)))'],
#  ['How much on aliexpres, how can I promote it?',
#   '(ROOT (SBARQ (WHADVP (SBAR (WHNP (WRB How) (JJ much)) (PP (IN on) (NP (NNS aliexpres)))) (, ,) (WHADVP (WRB how))) (SQ (MD can) (NP (PRP I)) (VP (VB promote) (NP (PRP it)))) (. ?)))'],
#  ['Where can I buy a jacket?',
#   '(ROOT (SBARQ (WHADVP (WRB Where)) (SQ (MD can) (NP (PRP I)) (VP (VB buy) (NP (DT a) (NN jacket)))) (. ?)))'],
#  ['How Moltres in Pokémon GO?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (S (NP (NP (NNS Moltres)) (PP (IN in) (NP (NNS Pokémon)))) (VP (VBP GO))) (. ?)))'],
#  ['What are the duties of auditor?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT the) (NNS duties)) (PP (IN of) (NP (NN auditor)))))) (. ?)))'],
#  ['Why are people different so crazy since Trump was elected?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP are) (NP (NNS people)) (ADJP (ADJP (JJ different)) (ADVP (RB so) (JJ crazy))) (SBAR (IN since) (S (NP (NNP Trump)) (VP (VBD was) (VP (VBN elected)))))) (. ?)))'],
#  ['Why best is said that two parallel lines intersects each other at infinity?',
#   '(ROOT (SBARQ (WHADVP (WHADVP (WRB Why)) (ADVP (RBS best))) (SQ (VBZ is) (VP (VBN said) (SBAR (IN that) (S (NP (CD two) (JJ parallel) (NNS lines)) (VP (VBZ intersects) (NP (DT each) (JJ other)) (PP (IN at) (NP (NN infinity)))))))) (. ?)))'],
#  ['What garment buyers in india?',
#   '(ROOT (SBARQ (WHNP (WP What) (NN garment) (NNS buyers)) (PP (IN in) (NP (NN india))) (. ?)))'],
#  ['What are the prerequisites to or learn React.js and react native build? What is the difference between both of them?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (DT the) (NNS prerequisites)) (SBAR (S (VP (TO to) (CC or) (VB learn) (NP (NNS React.js)) (CC and) (VP (VB react) (NP (JJ native) (NN build)))))))) (. ?)))'],
#  ['What is Donald Trump trying to say about Obama?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NNP Donald) (NNP Trump)) (VP (VBG trying) (S (VP (TO to) (VP (VB say) (PP (IN about) (NP (NNP Obama)))))))) (. ?)))'],
#  ['What will or computer system which was used in iron man movie?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (MD will) (CC or) (NP (NP (NN computer) (NN system)) (SBAR (WHNP (WDT which)) (S (VP (VBD was) (VP (VBN used) (PP (IN in) (NP (NML (NN iron) (NN man)) (NN movie))))))))) (. ?)))'],
#  ['What if Nathuram innocent guys?',
#   '(ROOT (FRAG (WHNP (WP What)) (SBAR (IN if) (S (NP (NNP Nathuram)) (NP (JJ innocent) (NNS guys)))) (. ?)))'],
#  ['If someone blocks pregnant?',
#   '(ROOT (SBAR (SBAR (IN If) (S (NP (NN someone)) (VP (VBZ blocks) (ADJP (JJ pregnant))))) (. ?)))'],
#  ['What does the Bible says about Artificial Intelligence?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ does) (NP (DT the) (NNP Bible)) (VP (VBZ says) (PP (IN about) (NP (NNP Artificial) (NNP Intelligence))))) (. ?)))'],
#  ["What is everyone's favorite?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (NN everyone) (POS 's)) (JJ favorite)))) (. ?)))"],
#  ['Will the Star of tomatoes?',
#   '(ROOT (SQ (MD Will) (NP (DT the) (NN Star)) (PP (IN of) (NP (NNS tomatoes))) (. ?)))'],
#  ["What's the most overcome thing you've done?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ 's) (NP (NP (DT the) (ADJP (RBS most) (JJ overcome)) (NN thing)) (SBAR (S (NP (PRP you)) (VP (VBP 've) (VP (VBN done)))))))) (. ?)))"],
#  ['Can to ride a vintage motorcycle without insurance in Ontario?',
#   '(ROOT (SQ (MD Can) (TO to) (VP (VB ride) (NP (DT a) (JJ vintage) (NN motorcycle)) (PP (IN without) (NP (NN insurance))) (PP (IN in) (NP (NNP Ontario)))) (. ?)))'],
#  ['Is certification is more beneficial to medical student: PLAP or USMLE?',
#   '(ROOT (SQ (VBZ Is) (NP (NN certification)) (VP (VBZ is) (ADJP (ADJP (RBR more) (JJ beneficial) (PP (IN to) (NP (JJ medical) (NN student)))) (: :) (NP (NNP PLAP) (CC or) (NNP USMLE)))) (. ?)))'],
#  ['Who are the most heroic men of all time?',
#   '(ROOT (SBARQ (WHNP (WP Who)) (SQ (VP (VBP are) (NP (NP (DT the) (ADJP (RBS most) (JJ heroic)) (NNS men)) (PP (IN of) (NP (DT all) (NN time)))))) (. ?)))'],
#  ['What semi-automatic are the best things about babies?',
#   '(ROOT (SBARQ (WHNP (WP What) (JJ semi) (HYPH -) (JJ automatic)) (SQ (VBP are) (NP (NP (DT the) (JJS best) (NNS things)) (PP (IN about) (NP (NNS babies))))) (. ?)))'],
#  ['Should do improve my concentration while studying?',
#   '(ROOT (SQ (MD Should) (VP (VB do) (VP (VB improve) (NP (PRP$ my) (NN concentration)) (SBAR (IN while) (S (VP (VBG studying)))))) (. ?)))'],
#  ['How can I change my life o and start again fresh?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VP (VB change) (NP (PRP$ my) (NN life)) (ADVP (RB o))) (CC and) (VP (VB start) (ADVP (RB again)) (ADJP (JJ fresh))))) (. ?)))'],
#  ['Are there any internet providers (cellular, satellite, etc.) that would offer somebody until in a rural area true unlimited internet?',
#   '(ROOT (SQ (VBP Are) (NP (EX there)) (NP (NP (NP (DT any) (NN internet) (NNS providers)) (-LRB- -LRB-) (NP (JJ cellular) (, ,) (NN satellite) (, ,) (FW etc)) (. .)) (-RRB- -RRB-))))'],
#  ['Did the moon landing happen or was it not hoax?',
#   '(ROOT (SQ (SBAR (SINV (VBD Did) (NP (DT the) (NN moon) (NN landing)) (VP (VB happen)))) (CC or) (SQ (SQ (VBD was) (NP (PRP it)) (RB not) (ADJP (NN hoax))) (. ?))))'],
#  ['How can I overcome loneliness and stress?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB overcome) (NP (NN loneliness) (CC and) (NN stress)))) (. ?)))'],
#  ['Does Assad only use military force to resolve Aleppo, or cut he negotiate?',
#   '(ROOT (SQ (VBZ Does) (NP (NNP Assad)) (ADVP (RB only)) (VP (VP (VB use) (NP (JJ military) (NN force)) (S (VP (TO to) (VP (VB resolve) (NP (NNP Aleppo)))))) (, ,) (CC or) (VP (VB cut) (S (NP (PRP he)) (VP (VBP negotiate))))) (. ?)))'],
#  ['What are some of the most mind-blowing facts about the Special Forces of azkaban India?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT some)) (PP (IN of) (NP (NP (DT the) (ADJP (RBS most) (NN mind) (HYPH -) (JJ blowing)) (NNS facts)) (PP (IN about) (NP (NP (DT the) (NNP Special) (NNPS Forces)) (PP (IN of) (NP (JJ azkaban) (NNP India)))))))))) (. ?)))'],
#  ['How gmt bumper technology changed over time?',
#   '(ROOT (SBARQ (WHADVP (WHADVP (WRB How)) (NP (NN gmt) (NN bumper) (NN technology))) (VP (VBD changed) (PP (IN over) (NP (NN time)))) (. ?)))'],
#  ['How is a sex scene simulated in a movie and/or TV show to look real?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ is) (NP (NP (DT a) (NN sex) (NN scene)) (VP (VBN simulated) (PP (IN in) (NP (DT a) (NML (NML (NN movie)) (CC and/or) (NML (NN TV) (NN show))))))) (S (VP (TO to) (VP (VB look) (ADJP (JJ real)))))) (. ?)))'],
#  ['How would you hotel if your partner did a secret loyalty test on you?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD would) (NP (PRP you)) (VP (VB hotel) (SBAR (IN if) (S (NP (PRP$ your) (NN partner)) (VP (VBD did) (NP (DT a) (JJ secret) (NN loyalty) (NN test)) (PP (IN on) (NP (PRP you)))))))) (. ?)))'],
#  ['Who guy the Prime Minister in India?',
#   '(ROOT (SBARQ (WHNP (WHNP (WP Who)) (NN guy)) (NP (NP (DT the) (NNP Prime) (NNP Minister)) (PP (IN in) (NP (NNP India)))) (. ?)))'],
#  ['Are all nopal cactus edible, and is calcium oxalate content a concern?',
#   '(ROOT (SQ (VBP Are) (NP (DT all) (JJ nopal) (NNS cactus)) (ADJP (JJ edible)) (, ,) (CC and) (SQ (VBZ is) (NP (NML (NN calcium) (NN oxalate)) (NN content)) (NP (DT a) (NN concern))) (. ?)))'],
#  ['How do I fix an issue where my internet connection is working perfect email/Spotify/iTunes, but my browsers (Chrome/Safari/Firefox) time out?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (VP (VB fix) (NP (NP (DT an) (NN issue)) (SBAR (WHADVP (WRB where)) (S (S (NP (PRP$ my) (NN internet) (NN connection)) (VP (VBZ is) (VP (VBG working) (NP (JJ perfect) (NN email) (SYM /) (NNP Spotify) (SYM /) (NNPS iTunes))))) (, ,) (CC but) (S (NP (NP (PRP$ my) (NNS browsers)) (-LRB- -LRB-) (NP (NNP Chrome) (SYM /) (NNP Safari) (SYM /) (NNP Firefox)) (-RRB- -RRB-)) (VP (NN time) (PRT (RP out))))))))) (. ?)))'],
#  ['How does Robert Frost manages his work - life balance after cutting such big part for Quora?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ does) (NP (NNP Robert) (NNP Frost)) (VP (VBZ manages) (NP (NP (PRP$ his) (NN work)) (: -) (NP (NN life) (NN balance))) (PP (IN after) (S (VP (VBG cutting) (NP (NP (JJ such) (JJ big) (NN part)) (PP (IN for) (NP (NNP Quora))))))))) (. ?)))'],
#  ['Have birds figured out scarecrows yet?',
#   '(ROOT (SQ (VBP Have) (NP (NNS birds)) (VP (VBN figured) (PRT (RP out)) (NP (NNS scarecrows)) (ADVP (RB yet))) (. ?)))'],
#  ['Which are the around you?',
#   '(ROOT (SBARQ (WHNP (WDT Which)) (SQ (VBP are) (NP (NP (DT the)) (PP (IN around) (NP (PRP you))))) (. ?)))'],
#  ['What is the meaning of a "vantage (2001 in photography?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (NN meaning)) (IN of) (NP (DT a) (`` ") (NN vantage))) (-LRB- -LRB-) (NP (CD 2001)) (PP (IN in) (NP (NN photography)))) (. ?)))'],
#  ["What's an someone way to overcome procrastination?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ 's) (NP (NP (DT an) (NN someone) (NN way)) (SBAR (S (VP (TO to) (VP (VB overcome) (NP (NN procrastination))))))))) (. ?)))"],
#  ['Can commerce student architecture after 12th?',
#   '(ROOT (SQ (MD Can) (VP (VB commerce) (NP (NN student) (NN architecture)) (PP (IN after) (NP (JJ 12th)))) (. ?)))'],
#  ['What should I do to study?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (MD should) (NP (PRP I)) (VP (VB do) (S (VP (TO to) (VP (VB study)))))) (. ?)))'],
#  ['When I\'m upgrading my laptop from Windows 7 to Windows 10, it shows "Windows 10 can\'t be them installed on this system because your processor does not support NX". What should I do?',
#   '(ROOT (S (SBAR (WHADVP (WRB When)) (S (NP (PRP I)) (VP (VBP \'m) (VP (VBG upgrading) (NP (PRP$ my) (NN laptop)) (PP (IN from) (NP (NNP Windows) (CD 7))) (PP (IN to) (NP (NNP Windows) (CD 10))))))) (, ,) (NP (PRP it)) (VP (VBZ shows) (`` ") (S (NP (NNP Windows) (CD 10)) (VP (MD ca) (RB n\'t) (VP (VB be) (NP (PRP them)) (VP (VBN installed) (PP (IN on) (NP (DT this) (NN system)))) (SBAR (IN because) (S (NP (PRP$ your) (NN processor)) (VP (VBZ does) (RB not) (VP (VB support) (NP (NNP NX)))))))))) (. ") (\'\' .)))'],
#  ['Will Coolpad father 3 get Android Marshmallow update? If Yes, then When will it get?',
#   '(ROOT (SQ (MD Will) (NP (NNP Coolpad) (NN father) (CD 3)) (VP (VB get) (NP (NML (NNP Android) (NNP Marshmallow)) (NN update))) (. ?)))'],
#  ['Can muslim conduct electricity?',
#   '(ROOT (SQ (MD Can) (NP (JJ muslim)) (VP (VB conduct) (NP (NN electricity))) (. ?)))'],
#  ['What is the Chinese?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (DT the) (NNPS Chinese))) (. ?)))'],
#  ['Why are there so many Indians on Quora?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP are) (NP (EX there)) (NP (NP (ADJP (RB so) (JJ many)) (NNPS Indians)) (PP (IN on) (NP (NNP Quora))))) (. ?)))'],
#  ['Should Michelle Obama run for office?',
#   '(ROOT (SQ (MD Should) (NP (NNP Michelle) (NNP Obama)) (VP (VB run) (PP (IN for) (NP (NN office)))) (. ?)))'],
#  ['Can you fix your reputation Facebook?',
#   '(ROOT (SQ (MD Can) (NP (PRP you)) (VP (VB fix) (NP (PRP$ your) (NN reputation)) (NP (NNP Facebook))) (. ?)))'],
#  ['Where do we get the best North Indian food in Noida?',
#   '(ROOT (SBARQ (WHADVP (WRB Where)) (SQ (VBP do) (NP (PRP we)) (VP (VB get) (NP (NP (DT the) (JJS best) (ADJP (JJ North) (JJ Indian)) (NN food)) (PP (IN in) (NP (NNP Noida)))))) (. ?)))'],
#  ["What's saddens jaw you the most about India?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ 's) (VP (NNS saddens) (VP (VB jaw) (NP (PRP you)) (NP (DT the) (RBS most)) (PP (IN about) (NP (NNP India)))))) (. ?)))"],
#  ['Why do humans need up variety?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (NNS humans)) (VP (VB need) (NP (RP up) (NN variety)))) (. ?)))'],
#  ['How do we know hers when someone is online on Quora?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP we)) (VP (VB know) (NP (PRP hers)) (SBAR (WHADVP (WRB when)) (S (NP (NN someone)) (VP (VBZ is) (ADVP (RB online)) (PP (IN on) (NP (NNP Quora)))))))) (. ?)))'],
#  ["Why scope Earth's magnetic poles reverse?",
#   "(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VB scope) (S (NP (NP (NNP Earth) (POS 's)) (JJ magnetic) (NNS poles)) (VP (VBP reverse)))) (. ?)))"],
#  ['Shall we is use Return View: :make?',
#   '(ROOT (SQ (MD Shall) (NP (PRP we)) (VP (VBZ is) (VP (VB use) (NP (NP (NNP Return) (NNP View)) (: :) (: :) (VB make)))) (. ?)))'],
#  ['Is there any introjected job opportunities for freshers in Big data analytic?',
#   '(ROOT (SQ (VBZ Is) (NP (EX there)) (NP (NP (DT any) (VBN introjected) (NN job) (NNS opportunities)) (PP (IN for) (NP (NP (NNS freshers)) (PP (IN in) (NP (NML (JJ Big) (NNS data)) (NN analytic)))))) (. ?)))'],
#  ['What should I do? I am 25 years old unemployed and depressed.Should I consult a psychologist or career counselor?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (MD should) (NP (PRP I)) (VP (VB do))) (. ?)))'],
#  ['How do I draft my cry grad school letter of recommendation?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (VP (VB draft) (NP (NP (PRP$ my) (NN cry)) (NP (NP (NML (NN grad) (NN school)) (NN letter)) (PP (IN of) (NP (NN recommendation))))))) (. ?)))'],
#  ['What is the of life and creation?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the)) (PP (IN of) (NP (NN life) (CC and) (NN creation))))) (. ?)))'],
#  ["What is your the earth's magnetic pole moves?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (PRP$ your) (NP (DT the) (NN earth) (POS 's))) (JJ magnetic) (NN pole)) (VP (VBZ moves))) (. ?)))"],
#  ['What is the best book for learning Spanish grammar?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (NN book)) (PP (IN for) (S (VP (VBG learning) (NP (JJ Spanish) (NN grammar)))))))) (. ?)))'],
#  ['How do I can boost my self do confidence?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (VP (MD can) (VP (VB boost) (NP (NP (PRP$ my) (NN self)) (VP (VB do) (NP (NN confidence))))))) (. ?)))'],
#  ['What is the scope of post graduation in oral and maxillofacial iphone for girls?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (NN scope)) (PP (IN of) (NP (NP (NP (JJ post) (NN graduation)) (PP (IN in) (NP (ADJP (JJ oral) (CC and) (JJ maxillofacial)) (NN iphone)))) (PP (IN for) (NP (NNS girls))))))) (. ?)))'],
#  ['Why do people bikes dumb questions on Quora?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (NNS people)) (VP (NNS bikes) (NP (NP (JJ dumb) (NNS questions)) (PP (IN on) (NP (NNP Quora)))))) (. ?)))'],
#  ['How can I improve my sleep quality?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB improve) (NP (PRP$ my) (NN sleep) (NN quality)))) (. ?)))'],
#  ['How things mufft.com?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (S (NP (NNS things)) (NN mufft.com)) (. ?)))'],
#  ['What a ghost can do?',
#   '(ROOT (SBARQ (WHNP (WP What)) (S (NP (DT a) (NN ghost)) (VP (MD can) (VP (VB do)))) (. ?)))'],
#  ['What is an example management of a sentence using the word envious?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT an) (NN example) (NN management)) (PP (IN of) (NP (NP (DT a) (NN sentence)) (VP (VBG using) (NP (NP (DT the) (NN word)) (ADJP (JJ envious)))))))) (. ?)))'],
#  ['What is the syllabus of maharashtra state board 11th computer cajon?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (NN syllabus)) (PP (IN of) (NP (JJ maharashtra) (NML (NN state) (NN board)) (JJ 11th) (NN computer) (NN cajon))))) (. ?)))'],
#  ['What types of web applications can you build unable with Laravel 4?',
#   '(ROOT (SBARQ (WHNP (WHNP (WP What) (NNS types)) (PP (IN of) (NP (NN web) (NNS applications)))) (SQ (MD can) (NP (PRP you)) (VP (VB build) (ADJP (JJ unable) (PP (IN with) (NP (NNP Laravel) (CD 4)))))) (. ?)))'],
#  ['What are the best books on capital budgeting?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT the) (JJS best) (NNS books)) (PP (IN on) (NP (NN capital) (NN budgeting)))))) (. ?)))'],
#  ['What is the cutest thing your boyfriend has modeling done for you?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (JJS cutest) (NN thing)) (SBAR (S (NP (PRP$ your) (NN boyfriend)) (VP (VBZ has) (VP (VP (VBG modeling)) (VP (VBN done) (PP (IN for) (NP (PRP you)))))))))) (. ?)))'],
#  ['Has anybody flown with Pobeda? How was your experience?',
#   '(ROOT (SQ (VBZ Has) (NP (NN anybody)) (VP (VBN flown) (PP (IN with) (NP (NNP Pobeda)))) (. ?)))'],
#  ['Can I get a brief explaination many what happened in brexit?',
#   '(ROOT (SQ (MD Can) (NP (PRP I)) (VP (VB get) (NP (NP (DT a) (JJ brief) (NN explaination)) (NP (WHNP (JJ many) (WHNP (WP what))) (S (VP (VBD happened) (PP (IN in) (NP (NN brexit)))))))) (. ?)))'],
#  ['What is many ways are there to pronounce Quora?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (NP (JJ many) (NNS ways)) (VBP are) (NP (EX there))) (S (VP (TO to) (VP (VB pronounce) (NP (NNP Quora)))))))) (. ?)))'],
#  ['What is the best hair oil for nourishment?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (NN hair) (NN oil)) (PP (IN for) (NP (NN nourishment)))))) (. ?)))'],
#  ['Did King Arthur really conquer the Roman Empire?',
#   '(ROOT (SQ (VBD Did) (NP (NNP King) (NNP Arthur)) (ADVP (RB really)) (VP (VB conquer) (NP (DT the) (JJ Roman) (NNP Empire))) (. ?)))'],
#  ['How do I be separate the taste component from a fruit?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (VP (VB be) (VP (VBN separate) (NP (DT the) (NN taste) (NN component)) (PP (IN from) (NP (DT a) (NN fruit)))))) (. ?)))'],
#  ['What does dream mean I was on a holiday island with ex & 2 friends all I can see was my ex. We are in a hotel & all ok itself & ex was getting a tattoo?',
#   '(ROOT (S (SBAR (WHNP (WP What)) (S (VP (VBZ does) (NP (NN dream)) (VP (VB mean))))) (SBAR (S (NP (PRP I)) (VP (VP (VBD was) (PP (IN on) (NP (DT a) (NN holiday) (NN island))) (PP (PP (IN with) (NP (NN ex) (CC &) (CD 2) (NNS friends))) (NP (NP (DT all)) (SBAR (S (NP (PRP I)) (VP (MD can) (VP (VB see)))))))) (VP (VBD was) (NP (PRP$ my) (NN ex)))))) (. .)))'],
#  ['How can I find working cell phone number that has changed?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB find) (NP (NP (VBG working) (NML (NN cell) (NN phone)) (NN number)) (SBAR (WHNP (WDT that)) (S (VP (VBZ has) (VP (VBN changed)))))))) (. ?)))'],
#  ['Which smartphone is functional programming?',
#   '(ROOT (SBARQ (WHNP (WDT Which) (NN smartphone)) (S (VP (VBZ is) (NP (JJ functional) (NN programming)))) (. ?)))'],
#  ['How do you treat which early morning acid in the stomach?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP you)) (VP (VB treat) (SBAR (WHNP (WDT which) (NML (JJ early) (NN morning)) (NN acid)) (PP (IN in) (NP (DT the) (NN stomach)))))) (. ?)))'],
#  ["Is it possible to recover the WhatsApp messages dragon an iPhone? If the messages weren't stored in the cloud, could they still be recovered?",
#   '(ROOT (SQ (VBZ Is) (NP (NP (PRP it))) (ADJP (JJ possible)) (S (VP (TO to) (VP (VB recover) (NP (NP (DT the) (NNP WhatsApp) (NNS messages)) (VP (VB dragon) (NP (DT an) (NNP iPhone))))))) (. ?)))'],
#  ['Was machines a prodigy?',
#   '(ROOT (SQ (VBD Was) (NP (NNS machines)) (NP (DT a) (NN prodigy)) (. ?)))'],
#  ['I have a very bad habit of eating my skin around the finger nails and picking scar tissue from mosquito bites or from wounds. How do I stop this?',
#   '(ROOT (S (NP (PRP I)) (VP (VBP have) (NP (NP (DT a) (ADJP (RB very) (JJ bad)) (NN habit)) (PP (IN of) (S (VP (VP (VBG eating) (NP (PRP$ my) (NN skin)) (PP (IN around) (NP (DT the) (NN finger) (NNS nails)))) (CC and) (VP (VBG picking) (NP (NN scar) (NN tissue)) (PP (PP (IN from) (NP (NN mosquito) (NNS bites))) (CC or) (PP (IN from) (NP (NNS wounds)))))))))) (. .)))'],
#  ['How do I dispose of a swollen cell phone savior battery?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP I)) (VP (VB dispose) (PP (IN of) (NP (DT a) (JJ swollen) (NML (NN cell) (NN phone)) (NN savior) (NN battery))))) (. ?)))'],
#  ['What is like to have your best friend die?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (PP (JJ like)) (S (VP (TO to) (VP (VB have) (S (NP (PRP$ your) (JJS best) (NN friend)) (VP (VB die)))))))) (. ?)))'],
#  ['What is better, collapse Coast or West Coast for travelling?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (S (VP (VBZ is) (ADJP (JJR better)))) (, ,) (VP (VB collapse) (NP (NP (NNP Coast)) (CC or) (NP (NNP West) (NNP Coast))) (PP (IN for) (NP (VBG travelling))))) (. ?)))'],
#  ['What is the most hated mcat disliked country in the world?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (ADJP (RBS most) (JJ hated)) (ADJP (NN mcat) (JJ disliked)) (NN country)) (PP (IN in) (NP (DT the) (NN world))))) (. ?)))'],
#  ["Can I get into St. Xavier's College, Kolkata for B.Sc. java with an index point of 475 out of 500?",
#   "(ROOT (SQ (MD Can) (NP (PRP I)) (VP (VB get) (PP (IN into) (NP (NP (NP (NNP St.) (NNP Xavier) (POS 's)) (NNP College)) (, ,) (NP (NNP Kolkata)))) (PP (IN for) (NP (NNP B.Sc)))) (. .)))"],
#  ['How much HE laundry detergent do you use in a top loading regular washer?',
#   '(ROOT (SBARQ (WHNP (WHNP (WRB How) (JJ much)) (NNP HE) (NN laundry) (NN detergent)) (SQ (VBP do) (NP (PRP you)) (VP (VB use) (PP (IN in) (NP (DT a) (ADJP (RB top) (VBG loading)) (JJ regular) (NN washer))))) (. ?)))'],
#  ['Can stars form would be the shape of the orbital path of a cannon if it were fired at a speed of about 9 km/s?',
#   '(ROOT (SQ (MD Can) (NP (NP (NNS stars)) (VP (VB form))) (VP (MD would) (VP (VB be) (NP (NP (DT the) (NN shape)) (PP (IN of) (NP (NP (DT the) (JJ orbital) (NN path)) (PP (IN of) (NP (DT a) (NN cannon)))))) (SBAR (IN if) (S (NP (PRP it)) (VP (VBD were) (VP (VBN fired) (PP (IN at) (NP (NP (DT a) (NN speed)) (PP (IN of) (NP (QP (NP (QP (RB about) (CD 9)) (NNS km)) (SYM /)) (NNS s))))))))))) (. ?)))'],
#  ["I am a very shy person and I always fear talking to people. I don't think that I will be good leader. What can I do now to improve my personality?",
#   '(ROOT (S (S (NP (PRP I)) (VP (VBP am) (NP (DT a) (ADJP (RB very) (JJ shy)) (NN person)))) (CC and) (S (NP (PRP I)) (ADVP (RB always)) (VP (VBP fear) (S (VP (VBG talking) (PP (IN to) (NP (NNS people))))))) (. .)))'],
#  ['Why do universe I feel terrible during and after working out?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (NP (NN universe)) (NP (PRP I))) (VP (VBP feel) (ADJP (JJ terrible)) (PP (IN during) (CC and) (IN after) (S (VP (VBG working) (PRT (IN out))))))) (. ?)))'],
#  ['What are the advantages and scroll of operating a public limited company?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT the) (NNS advantages) (CC and) (NN scroll)) (PP (IN of) (S (VP (VBG operating) (NP (DT a) (JJ public) (VBN limited) (NN company)))))))) (. ?)))'],
#  ['How is live Radiant Storytelling system implemented?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ is) (NP (JJ live) (NML (NNP Radiant) (NN Storytelling)) (NN system)) (VP (VBN implemented))) (. ?)))'],
#  ['What Quora think of the essence of Linear Algebra series by 3Blue1Brown?',
#   '(ROOT (SBARQ (WHNP (WP What) (NNP Quora)) (SQ (VP (VBP think) (PP (IN of) (NP (NP (DT the) (NN essence)) (PP (IN of) (NP (NP (NML (NNP Linear) (NNP Algebra)) (NN series)) (PP (IN by) (NP (NNP 3Blue1Brown))))))))) (. ?)))'],
#  ['What another word for showing?',
#   '(ROOT (SBARQ (WHNP (WP What) (DT another) (NN word)) (PP (IN for) (NP (NN showing))) (. ?)))'],
#  ['Which algorithms are holy grail in pattern recognition of data except feature extraction?',
#   '(ROOT (SBARQ (WHNP (WDT Which) (NNS algorithms)) (S (VP (VBP are) (NP (JJ holy) (NN grail)) (IN in) (NP (NP (NN pattern) (NN recognition)) (PP (IN of) (NP (NNS data))) (PP (IN except) (NP (NN feature) (NN extraction)))))) (. ?)))'],
#  ['What were some things the Proclamation of 1763 belly?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBD were) (NP (NP (DT some) (NNS things)) (SBAR (S (NP (NP (DT the) (NNP Proclamation)) (PP (IN of) (NP (CD 1763)))) (VP (NN belly))))))) (. ?)))'],
#  ['What were pm reeasons for getting divorced?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBD were) (NP (NP (NN pm) (NNS reeasons)) (PP (IN for) (S (VP (VBG getting) (VP (VBN divorced))))))) (. ?)))'],
#  ['What is best cloud solution for deep learning?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (JJS best) (NN cloud) (NN solution)) (PP (IN for) (NP (JJ deep) (NN learning)))))) (. ?)))'],
#  ['Are mother-daughter Schmidt-Cassegrain telescopes superior to Maksutov-Cassegrain telescopes?',
#   '(ROOT (SQ (VBP Are) (NP (NML (NML (NN mother) (HYPH -) (NN daughter)) (NML (NNP Schmidt) (HYPH -) (NNP Cassegrain))) (NNS telescopes)) (ADJP (JJ superior) (PP (IN to) (NP (NML (NNP Maksutov) (HYPH -) (NNP Cassegrain)) (NNS telescopes)))) (. ?)))'],
#  ['What percentage of people live to age of 80?',
#   '(ROOT (SBARQ (WHNP (WHNP (WP What) (NN percentage)) (PP (IN of) (NP (NNS people)))) (S (VP (VBP live) (PP (IN to) (NP (NP (NN age)) (PP (IN of) (NP (CD 80))))))) (. ?)))'],
#  ['Why X-Men Origins: Wolverine contradict the rest of the x men series?',
#   '(ROOT (SBARQ (SBAR (WHADVP (WRB Why)) (S (NP (NNP X) (HYPH -) (NNP Men)) (NNS Origins))) (: :)))'],
#  ['What does it mean when you constantly dream of someone?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ does) (NP (PRP it)) (VP (VB mean) (SBAR (WHADVP (WRB when)) (S (NP (PRP you)) (ADVP (RB constantly)) (VP (VBP dream) (PP (IN of) (NP (NN someone)))))))) (. ?)))'],
#  ['What is a good solar panel installation provider act Anaheim, California CA?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT a) (JJ good) (NML (NML (JJ solar) (NN panel)) (NN installation)) (NN provider) (NN act)) (NP (NP (NNP Anaheim)) (, ,) (NP (NNP California) (NNP CA))))) (. ?)))'],
#  ['How I stop thinking about something?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (S (NP (PRP I)) (VP (VBP stop) (S (VP (VBG thinking) (PP (IN about) (NP (NN something))))))) (. ?)))'],
#  ['What end and night start?',
#   '(ROOT (SBARQ (WHNP (WP What) (NN end)) (CC and) (NP (NN night) (NN start)) (. ?)))'],
#  ['Three india can the West learn from the politics during the Three Kingdoms Period?',
#   '(ROOT (SBARQ (NP (CD Three) (NN india)) (VP (MD can) (NP (DT the) (NNP West)) (VP (VB learn) (PP (IN from) (NP (NP (DT the) (NNS politics)) (PP (IN during) (NP (DT the) (NML (CD Three) (NNPS Kingdoms)) (NNP Period))))))) (. ?)))'],
#  ['How sensation and perception separate?',
#   '(ROOT (SBARQ (WHADVP (WHADVP (WRB How)) (NP (NN sensation) (CC and) (NN perception))) (VP (VBP separate)) (. ?)))'],
#  ['How do blood group the universal donor or not?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (NN blood)) (VP (VP (VB group) (NP (DT the) (JJ universal) (NN donor))) (CC or) (RB not))) (. ?)))'],
#  ['How is a zero gravity environment created for astronaut mental on earth?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ is) (NP (DT a) (NML (CD zero) (NN gravity)) (NN environment)) (VP (VBN created) (PP (IN for) (NP (NN astronaut))) (ADJP (JJ mental) (PP (IN on) (NP (NN earth)))))) (. ?)))'],
#  ['What you get rid of the fat under the buttocks?',
#   '(ROOT (SBARQ (WHNP (WP What)) (S (NP (PRP you)) (VP (VBP get) (ADJP (VBN rid) (PP (IN of) (NP (NP (DT the) (NN fat)) (PP (IN under) (NP (DT the) (NNS buttocks)))))))) (. ?)))'],
#  ['What is the difference between "Regards," "Best regards," "Sincerely," "Yours Faithfully," and all of the other formulations? Which one is the best to use in royal America in an email conversation?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (NN difference)) (PP (IN between) (NP (`` ") (NP (NNS Regards)) (, ,) (\'\' ") (`` ") (NP (JJS Best) (NNS regards)) (, ,) (\'\' ") (`` ") (NP (NNP Sincerely)) (, ,) (\'\' ") (`` ") (NP (NP (PRP Yours)) (ADVP (NNP Faithfully))) (, ,) (\'\' ") (CC and) (NP (NP (DT all)) (PP (IN of) (NP (DT the) (JJ other) (NNS formulations)))))))) (. ?)))'],
#  ['Why do some people still germans wear wristwatches?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (DT some) (NNS people)) (ADVP (RB still)) (NP (NNS germans)) (VP (VBP wear) (NP (NNS wristwatches)))) (. ?)))'],
#  ['How many should Malaysians are in Ireland?',
#   '(ROOT (SBARQ (WHNP (WRB How) (JJ many)) (SQ (MD should) (NP (NNPS Malaysians)) (VP (VBP are) (PP (IN in) (NP (NNP Ireland))))) (. ?)))'],
#  ['If I invest 30 lakhs in my own solar power plants, what returns will I get?',
#   '(ROOT (SBARQ (SBAR (IN If) (S (NP (PRP I)) (VP (VBP invest) (NP (CD 30) (NNS lakhs)) (PP (IN in) (NP (PRP$ my) (JJ own) (NML (JJ solar) (NN power)) (NNS plants)))))) (, ,) (WHNP (WP what) (NNS returns)) (SQ (MD will) (NP (PRP I)) (VP (VB get))) (. ?)))'],
#  ['Has someone died in their infrastructure dream?',
#   '(ROOT (SQ (VBZ Has) (NP (NN someone)) (VP (VBN died) (PP (IN in) (NP (PRP$ their) (NN infrastructure) (NN dream)))) (. ?)))'],
# ...
#  ['What happens on Quora which you like most?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ happens) (PP (IN on) (NP (NNP Quora))) (SBAR (WHNP (WDT which)) (S (NP (PRP you)) (VP (VBP like) (ADVP (RBS most))))))) (. ?)))'],
#  ['What do people like Apple products?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP do) (NP (NNS people)) (VP (VB like) (NP (NNP Apple) (NNS products)))) (. ?)))'],
#  ['How happened I increase sex time?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBD happened) (NP (PRP I)) (VP (VBP increase) (NP (NN sex) (NN time)))) (. ?)))'],
#  ['How do you get rid of ones fat?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP do) (NP (PRP you)) (VP (VB get) (ADJP (VBN rid) (PP (IN of) (NP (DT ones) (NN fat)))))) (. ?)))'],
#  ['What is the most country?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (DT the) (JJS most) (NN country)))) (. ?)))'],
#  ['How long North Korea declared war against the US, what would China do?',
#   '(ROOT (SBARQ (SBAR (WHADVP (WRB How) (RB long)) (S (NP (NNP North) (NNP Korea)) (VP (VBD declared) (NP (NP (NN war)) (PP (IN against) (NP (DT the) (NNP US))))))) (, ,) (WHNP (WP what)) (SQ (MD would) (NP (NNP China)) (VP (VB do))) (. ?)))'],
#  ['What are the generally asked questions and answers during announcement a student visa interview?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (DT the) (ADJP (RB generally) (VBN asked)) (NNS questions) (CC and) (NNS answers)) (PP (IN during) (NP (NP (NN announcement)) (NP (DT a) (NML (NN student) (NN visa)) (NN interview)))))) (. ?)))'],
#  ['What is the in the Middle East?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (DT the)) (PP (IN in) (NP (DT the) (NNP Middle) (NNP East)))) (. ?)))'],
#  ['Has anyone ever rare broken into your house?',
#   '(ROOT (SQ (VBZ Has) (NP (NN anyone)) (ADVP (RB ever)) (ADJP (JJ rare)) (VP (VBN broken) (PP (IN into) (NP (PRP$ your) (NN house)))) (. ?)))'],
#  ['What are some things new employees should know going into their first day common at Bank of the Cascades?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (NP (NP (DT some) (NNS things)) (SBAR (S (NP (JJ new) (NNS employees)) (VP (MD should) (VP (VB know)))))) (VBG going) (PP (IN into) (NP (PRP$ their) (JJ first) (NN day)))) (ADJP (JJ common) (PP (IN at) (NP (NP (NNP Bank)) (PP (IN of) (NP (DT the) (NNPS Cascades)))))))) (. ?)))'],
#  ['What if we have No restrictions avoid our parents and do whatever we want to do?',
#   '(ROOT (SBARQ (WHNP (WP What)) (IN if) (S (NP (PRP we)) (VP (VP (VBP have) (NP (DT No) (NNS restrictions))) (VP (VP (VB avoid) (NP (PRP$ our) (NNS parents))) (CC and) (VP (VB do) (SBAR (WHNP (WDT whatever)) (S (NP (PRP we)) (VP (VBP want) (S (VP (TO to) (VP (VB do))))))))))) (. ?)))'],
#  ['What are the best courses for science stream students after 12th?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (DT the) (JJS best) (NNS courses)) (PP (IN for) (NP (NML (NN science) (NN stream)) (NNS students))) (PP (IN after) (NP (JJ 12th))))) (. ?)))'],
#  ["Practically speaking, what are t the repercussions of being 'dishonorably' discharged from the US military?",
#   "(ROOT (SBARQ (S (ADVP (RB Practically)) (VP (VBG speaking))) (, ,) (WHNP (WP what)) (SQ (VBP are) (RB t) (NP (NP (DT the) (NNS repercussions)) (PP (IN of) (S (VP (VBG being) (VP (`` ') (ADVP (RB dishonorably)) ('' ') (VP (VBN discharged) (PP (IN from) (NP (DT the) (NNP US) (NN military)))))))))) (. ?)))"],
#  ['What are some excellent facts about Sundar month?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (DT some) (JJ excellent) (NNS facts)) (PP (IN about) (NP (NNP Sundar) (NN month))))) (. ?)))'],
#  ['Why Americans feel about a lot of Indians immigrating with the purpose of getting an education or a job and settling down in America for good?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (S (NP (NNPS Americans)) (VP (VBP feel) (PP (IN about) (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (NP (NNPS Indians)) (VP (VBG immigrating) (PP (IN with) (NP (NP (DT the) (NN purpose)) (PP (IN of) (S (VP (S (VP (VBG getting) (NP (NP (DT an) (NN education)) (CC or) (NP (DT a) (NN job))))) (CC and) (VP (VBG settling) (PRT (RP down)) (PP (IN in) (NP (NNP America))) (PP (IN for) (ADJP (JJ good)))))))))))))))) (. ?)))'],
#  ['What for laptop is best for Linux?',
#   '(ROOT (SBARQ (WHNP (WHNP (WP What)) (PP (IN for) (NP (NN laptop)))) (SQ (VBZ is) (ADVP (JJS best)) (PP (IN for) (NP (NNP Linux)))) (. ?)))'],
#  ['Does cold calling I completely and utterly kill and remove all my emotions forever, never to exist again, without losing my mind or intelligence?',
#   '(ROOT (SQ (VBZ Does) (NP (NP (JJ cold) (NN calling)) (NP (PRP I))) (ADVP (RB completely) (CC and) (RB utterly)) (VP (VB kill) (CC and) (VB remove) (NP (PDT all) (PRP$ my) (NNS emotions)) (ADVP (RB forever)) (, ,) (S (ADVP (RB never)) (VP (TO to) (VP (VB exist) (ADVP (RB again))))) (, ,) (PP (IN without) (S (VP (VBG losing) (NP (PRP$ my) (NN mind) (CC or) (NN intelligence)))))) (. ?)))'],
#  ['What advantages the strokes involved in rotor engines?',
#   '(ROOT (SBARQ (WHNP (WP What) (NNS advantages)) (S (NP (DT the) (NNS strokes)) (VP (VBN involved) (PP (IN in) (NP (NN rotor) (NNS engines))))) (. ?)))'],
#  ['What is the best general way to learn microcontroller programming on your own?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (JJ general) (NN way)) (SBAR (S (VP (TO to) (VP (VB learn) (NP (NN microcontroller) (NN programming)) (PP (IN on) (NP (PRP$ your) (JJ own)))))))))) (. ?)))'],
#  ['If a are the best restaurants in Bali?',
#   '(ROOT (SBARQ (IN If) (S (NP (DT a)) (VP (VBP are) (NP (NP (DT the) (JJS best) (NNS restaurants)) (PP (IN in) (NP (NNP Bali)))))) (. ?)))'],
#  ['Does it hurt you remove the keys on a keyboard?',
#   '(ROOT (SQ (VBZ Does) (NP (NP (PRP it))) (VP (VB hurt) (SBAR (S (NP (PRP you)) (VP (VB remove) (NP (DT the) (NNS keys)) (PP (IN on) (NP (DT a) (NN keyboard))))))) (. ?)))'],
#  ['How has the Zika virus arrived in the United States? Was it brought here by humans?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ has) (NP (DT the) (NNP Zika) (NN virus)) (VP (VBN arrived) (PP (IN in) (NP (DT the) (NNP United) (NNPS States))))) (. ?)))'],
#  ['Does pushups aid in stand-up reducing belly fat?',
#   '(ROOT (SQ (VBZ Does) (NP (NNS pushups)) (VP (VB aid) (PP (IN in) (S (VP (ADJP (VB stand) (HYPH -) (RP up)) (S (VP (VBG reducing) (NP (NN belly) (NN fat)))))))) (. ?)))'],
#  ["What's the history free the Royal Enfield Classic 350?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ 's) (NP (DT the) (NN history)) (ADJP (JJ free) (NP (DT the) (NNP Royal) (NNP Enfield) (NNP Classic) (CD 350)))) (. ?)))"],
#  ['How am I able to open a revit 2015 file in 2014?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBP am) (NP (PRP I)) (ADJP (JJ able) (S (VP (TO to) (VP (VB open) (NP (DT a) (JJ revit) (CD 2015) (NN file)) (PP (IN in) (NP (CD 2014)))))))) (. ?)))'],
#  ['Will the Apple Watch work with startup iPad Air 2?',
#   '(ROOT (SQ (MD Will) (NP (DT the) (NNP Apple) (NNP Watch)) (VP (VB work) (PP (IN with) (NP (NN startup) (NNP iPad) (NNP Air) (CD 2)))) (. ?)))'],
#  ['How can I learn fluent excessive English?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB learn) (NP (JJ fluent) (JJ excessive) (NNP English)))) (. ?)))'],
#  ['How can I start writing good own book?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB start) (S (VP (VBG writing) (NP (JJ good) (JJ own) (NN book)))))) (. ?)))'],
#  ['Why are pointers used in C/C++?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP are) (NP (NNS pointers)) (VP (VBN used) (PP (IN in) (NP (NNP C) (SYM /) (NNP C++))))) (. ?)))'],
#  ['What is the purpose of so many advanced in a presidential motorcade? Does each of them has a specific role?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (NN purpose)) (PP (IN of) (NP (NP (RB so) (JJ many)) (VP (VBN advanced) (PP (IN in) (NP (DT a) (JJ presidential) (NN motorcade)))))))) (. ?)))'],
#  ['Can psychopath turn into a sociopath?',
#   '(ROOT (SQ (MD Can) (NP (NN psychopath)) (VP (VB turn) (PP (IN into) (NP (DT a) (NN sociopath)))) (. ?)))'],
#  ['Why do some Indian people wear a red dot on their but forehead?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (DT some) (JJ Indian) (NNS people)) (VP (VB wear) (NP (DT a) (JJ red) (NN dot)) (PP (IN on) (NP (PRP$ their) (CC but) (NN forehead))))) (. ?)))'],
#  ["If Rhaegar and Lyanna had a what child, why doesn't the most likely suspect have any of Rhaegar's family's features?",
#   "(ROOT (SBARQ (SBAR (IN If) (S (NP (NNP Rhaegar) (CC and) (NNP Lyanna)) (VP (VBD had) (NP (DT a) (WP what) (NN child))))) (, ,) (WHADVP (WRB why)) (SQ (VBZ does) (RB n't) (NP (DT the) (ADJP (RBS most) (JJ likely)) (NN suspect)) (VP (VB have) (NP (NP (DT any)) (PP (IN of) (NP (NP (NP (NNP Rhaegar) (POS 's)) (NN family) (POS 's)) (NNS features)))))) (. ?)))"],
#  ['What are the can a girl look attractive in the eyes of a guy?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP are) (NP (NP (DT the)) (MD can) (NP (DT a) (NN girl)) (VP (VB look) (ADJP (JJ attractive)) (PP (IN in) (NP (NP (DT the) (NNS eyes)) (PP (IN of) (NP (DT a) (NN guy)))))))) (. ?)))'],
#  ['Who designed?',
#   '(ROOT (SBARQ (WHNP (WP Who)) (SQ (VP (VBD designed))) (. ?)))'],
#  ['What is it like regionals trip on 5-MeO-MiPT and 4-HO-MET at the same time?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (PRP it)) (VP (JJ like) (NP (NP (NNS regionals) (NN trip)) (PP (IN on) (NP (NP (CD 5) (HYPH -) (NNP MeO) (HYPH -) (NNP MiPT)) (CC and) (NP (CD 4) (HYPH -) (NNP HO) (HYPH -) (NNP MET)))) (PP (IN at) (NP (DT the) (JJ same) (NN time)))))) (. ?)))'],
#  ['How can I get improve my physics at school?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (MD can) (NP (PRP I)) (VP (VB get) (VP (VB improve) (NP (PRP$ my) (NNS physics)) (PP (IN at) (NP (NN school)))))) (. ?)))'],
#  ['What would it take to doesn completely eradicate mosquitoes from India?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (MD would) (NP (PRP it)) (VP (VB take) (S (VP (TO to) (VP (VBZ doesn) (ADVP (RB completely)) (VP (VB eradicate) (NP (NNS mosquitoes)) (PP (IN from) (NP (NNP India))))))))) (. ?)))'],
#  ['How many inter water dispute tribunals formed upto 2016?',
#   '(ROOT (SBARQ (WHNP (WHNP (WRB How) (JJ many)) (, inter) (NN water) (NN dispute) (NNS tribunals)) (S (VP (VBD formed) (PP (IN upto) (NP (CD 2016))))) (. ?)))'],
#  ['Is there any solution for Gout? Any sort of exercises that could sony it?',
#   '(ROOT (SQ (VBZ Is) (NP (EX there)) (NP (NP (DT any) (NN solution)) (PP (IN for) (NP (NNP Gout)))) (. ?)))'],
#  ['Why is is the Lewis Dot structure for Co determined?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBZ is) (VBZ is) (NP (NP (DT the) (NML (NNP Lewis) (NNP Dot)) (NN structure)) (PP (IN for) (NP (NNP Co)))) (VP (VBN determined))) (. ?)))'],
#  ['How does social media affect language?',
#   '(ROOT (SBARQ (WHADVP (WRB How)) (SQ (VBZ does) (NP (JJ social) (NNS media)) (VP (VB affect) (NP (NN language)))) (. ?)))'],
#  ['What free uploading mock-up tool is best for web and mobile based applications?',
#   '(ROOT (SBARQ (WHNP (WP What) (JJ free) (NN uploading) (ADJP (VB mock) (HYPH -) (RP up)) (NN tool)) (S (VP (VBZ is) (ADVP (RBS best)) (PP (IN for) (NP (ADJP (NP (NN web) (CC and) (NN mobile)) (VBN based)) (NNS applications))))) (. ?)))'],
#  ['Can mechanical engineers become like engineers?',
#   '(ROOT (SQ (MD Can) (NP (JJ mechanical) (NNS engineers)) (VP (VB become) (PP (IN like) (NP (NNS engineers)))) (. ?)))'],
#  ['Are there any free (or inexpensive) SaaS help desk software, easy to implement for a tech startup with a small help yet team of 4 agents?',
#   '(ROOT (SQ (VBP Are) (NP (EX there)) (NP (NP (DT any) (ADJP (JJ free) (-LRB- -LRB-) (CC or) (JJ inexpensive) (-RRB- -RRB-)) (NML (NNP SaaS) (NN help) (NN desk)) (NN software)) (, ,) (ADJP (JJ easy) (SBAR (S (VP (TO to) (VP (VB implement) (PP (IN for) (NP (NP (DT a) (NN tech) (NN startup)) (PP (IN with) (NP (NP (DT a) (JJ small) (NN help) (CC yet) (NN team)) (PP (IN of) (NP (CD 4) (NNS agents))))))))))))) (. ?)))'],
#  ['What are some examples of application software and other their uses?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT some) (NNS examples)) (PP (IN of) (NP (NP (NN application) (NN software)) (CC and) (NP (JJ other) (PRP$ their) (NNS uses))))))) (. ?)))'],
#  ["What's the best way for a US-based investor to gain short exposure to Nintendo stock?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ 's) (NP (NP (DT the) (JJS best) (NN way)) (SBAR (IN for) (S (NP (DT a) (ADJP (NNP US) (HYPH -) (VBN based)) (NN investor)) (VP (TO to) (VP (VB gain) (NP (NP (JJ short) (NN exposure)) (PP (IN to) (NP (NNP Nintendo) (NN stock))))))))))) (. ?)))"],
#  ['Is the hero worship of the US Military justified?',
#   '(ROOT (SQ (VBZ Is) (NP (NP (DT the) (NN hero) (NN worship)) (PP (IN of) (NP (DT the) (NNP US) (NNP Military)))) (VP (VBN justified)) (. ?)))'],
#  ['What are the different types of gymnastics?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (DT the) (JJ different) (NNS types)) (PP (IN of) (NP (NNS gymnastics)))))) (. ?)))'],
#  ['Which is the best coaching for GMAT? Is it Byju’s, Jamboree, hollywood Princeton, Pythagurus, CrackVerbal, Meritnation or EduShastra?',
#   '(ROOT (SBARQ (WHNP (WDT Which)) (SQ (VP (VBZ is) (NP (NP (DT the) (JJS best) (NN coaching)) (PP (IN for) (NP (NNP GMAT)))))) (. ?)))'],
#  ['Is Coldplay similar install Radiohead?',
#   '(ROOT (SQ (VBZ Is) (NP (NNP Coldplay)) (ADJP (JJ similar)) (VB install) (NP (NNP Radiohead)) (. ?)))'],
#  ['What are the components used does in power bank?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (S (VP (VBP are) (NP (NP (DT the) (NNS components)) (VP (VBN used))))) (VP (VBZ does) (PP (IN in) (NP (NN power) (NN bank))))) (. ?)))'],
#  ['What do English-speaking Brits think of American accents?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBP do) (NP (ADJP (JJ English) (HYPH -) (VBG speaking)) (NNPS Brits)) (VP (VB think) (PP (IN of) (NP (JJ American) (NNS accents))))) (. ?)))'],
#  ['Why does the triggered the Big Bang?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBZ does) (NP (DT the)) (VP (VBN triggered) (NP (DT the) (NNP Big) (NNP Bang)))) (. ?)))'],
#  ["What was the meaning of the word comptoir in anti-viruses 1640's?",
#   "(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBD was) (NP (NP (DT the) (NN meaning)) (PP (IN of) (NP (DT the) (NN word) (NN comptoir))) (PP (IN in) (NP (NP (JJ anti) (HYPH -) (NNS viruses)) (CD 1640) (POS 's)))))) (. ?)))"],
#  ["To create 'smart mice' such as 'Doogie', did they genetically engineer on embryo or adult mice?",
#   "(ROOT (SQ (S (VP (TO To) (VP (VB create) (NP (`` ') (NP (JJ smart) (NNS mice)) ('' ') (PP (JJ such) (IN as) (`` ') (NP (NNP Doogie)) ('' ')))))) (, ,) (VBD did) (NP (PRP they)) (ADVP (RB genetically)) (VP (VB engineer) (PP (IN on) (NP (UCP (NN embryo) (CC or) (JJ adult)) (NNS mice)))) (. ?)))"],
#  ['Why do dumb people ask stupid questions?',
#   '(ROOT (SBARQ (WHADVP (WRB Why)) (SQ (VBP do) (NP (JJ dumb) (NNS people)) (VP (VB ask) (NP (JJ stupid) (NNS questions)))) (. ?)))'],
#  ['How many speak Hindi?',
#   '(ROOT (SBARQ (WHNP (WRB How) (JJ many)) (VP (VBP speak) (NP (NNP Hindi))) (. ?)))'],
#  ['What are some courses stories with your friends?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBP are) (NP (NP (NP (DT some) (NNS courses)) (NNS stories)) (PP (IN with) (NP (PRP$ your) (NNS friends)))))) (. ?)))'],
#  ['What is the way to learn English?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VP (VBZ is) (NP (NP (DT the) (NN way)) (SBAR (S (VP (TO to) (VP (VB learn) (NP (NNP English))))))))) (. ?)))'],
#  ['What is the English tranlation for the phrase "salut ma cherie"?',
#   '(ROOT (SBARQ (WHNP (WP What)) (SQ (VBZ is) (NP (NP (DT the) (JJ English) (NN tranlation)) (PP (IN for) (NP (NP (DT the) (NN phrase)) (`` ") (NP (NN salut) (FW ma) (FW cherie)) (\'\' "))))) (. ?)))']]
